# %% [markdown]
# Clone the panza repository by running the following cell.

# %%
# !git clone https://github.com/IST-DASLab/PanzaMail.git
# %cd PanzaMail
# Out:
# Cloning into 'PanzaMail'...
# remote: Enumerating objects: 1879, done.
# remote: Counting objects: 100% (203/203), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 1879 (delta 159), reused 136 (delta 122), pack-reused 1676 (from 2)
# Receiving objects: 100% (1879/1879), 1.71 MiB | 26.99 MiB/s, done.
# Resolving deltas: 100% (1064/1064), done.
# /content/PanzaMail

# %% [markdown]
# Install all the required packages

# %%
# !pip install hydra-core langchain-community fastapi uvicorn pydantic python-dotenv gradio evaluate torchmetrics nltk accelerate mauve-text langdetect --quiet

# %%
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth
else:
    # !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft trl==0.15.2 triton cut_cross_entropy unsloth_zoo
    # !pip install sentencepiece protobuf "datasets>=3.4.1" huggingface_hub hf_transfer
    # !pip install --no-deps unsloth

# %%
from unsloth import FastLanguageModel
import json
import re
import sys
import hydra
import torch
import numpy as np
from datasets import load_dataset
from transformers import TextStreamer, AutoConfig, AutoTokenizer
import os
from typing import Dict
from omegaconf import OmegaConf
from unsloth.chat_templates import get_chat_template
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported
import re
import pandas as pd
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) Y
# Token is valid (permission: fineGrained).
# The token `panza-preetika` has been saved to /root/.cache/huggingface/stored_tokens
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `panza-preetika`

# %% [markdown]
# Download your emails

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cp /content/drive/MyDrive/panza/Sent.mbox /content/PanzaMail/data/Sent.mbox

# %% [markdown]
# ##Configuration
#
# Now from the left panel, open the file PanzaMail/scripts/config.sh and configure the parameters according to this set of [instructions](https://github.com/IST-DASLab/PanzaMail?tab=readme-ov-file#step-1-environment-configuration). Additionally, you would want to edit your prompt preambles (under PanzaMail/prompt_preambles).

# %%
script_dir = os.path.dirname(os.path.abspath('/content/PanzaMail/scripts/prepare_data.py'))  # location of prepare_data.py
src_path = os.path.join(script_dir, '..', 'src')
sys.path.insert(0, os.path.abspath(src_path))

# %%
from panza import PanzaWriter  # The import also loads custom Hydra resolvers
from panza.entities import Document, Email, SummarizationInstruction, EmailInstruction
from panza.retriever import DocumentRetriever
from panza.data_preparation.extract_emails import extract_emails
from panza.data_preparation.prepare_raft_emails import prepare_raft_emails
from panza.data_preparation.rag import create_vector_store
from panza.interface.json import compute_rouge_scores, compute_bleu_scores, compute_mauve_score
# Out:
#      .    .        .                    .    .    .
#                    ...  .  .    .          . .       .    .
#                        .   .  .        . . =%[ :+.     .
#        .          .            .         .~@% +@(
#  .  ..     ~<:           .  .       .     >@^.@)         .
#       .  . :}:      .            .        *@@@@@{^=-.
#  .       ={@@~ .     .      .            .)@@@@@@@@@#= .
#        *%@@@@^     . .   ~^^             >@@@@@@@@@%(=.
#   (@%@@@@@@@@[       =#@@@@@@@@@@@#=    -}@@@@@@]..*=
#   ^@@@@@@@@@@%..  :<#@@@@@@@@@@@{=    ..:}@@@@@-)       ..
#   ~@@@@@@@@@@@-:[@@@@@@@@@@@@@@%+ .     =#@@@@@+* ..       .
#   :@@@@@@#^:.^*>#@%#{@@@@@@@@@@@#  ..+-.^@@@@@@<--
#   .}@@@[+    -(  .  .<@@@@@@@@@@^   ^%[=)@@@@@@~<(
#  .  ..       +@*. *}@@@@@@@@@@@@()>+)@@+=%@@@@@+}{= .
#              {@@#%@@@@@@@@@@@@@@@%{@@@%+]@@@@@@+
#         .    =@@@@@@@@@@@@@@@@@@@@@{#{*.(@@@@@@*
#        .      -@][[#@@@@@@@@@@@@@@@@@).=#@@@@@@*
#      +)}[{}*   #..-@@@@@@@@@@@@@@@@@@%>(@@@@@@@^
#   . ~[@@@@@@^:=#{#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@<. .
#    ~#@@@@@@#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@%
#   .:)@@@@(:~%@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@*
#     ~{@#<. <@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@#..         ..
#       ==   (@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@>    .      .
#         . .>@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@]         .
#     .      :%@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@(.
#         .   ^@@@@@@@@@@@@@@@@@@@@@@@@@@@@@~
#         ...  ~@@@@@@@@@@@@@@@@@@@@@@@@@[~     .          .
#     .   .  .  >@@@@@@@}=:=+^>^+@@@@@@@[:  .            .
# .            ..>@@@@@}-        +@@@@@]:               .  ..
# .               :#<<(           -{](>                .
#       .    .   ..(]>}+~~~=======+}(((~-::... .   ..
#      .:~=+^>)][[}{#%%@@@@@@@@@@@@@@@@@%%#{}}[])<>*+=-:.  .
#     .        . .         . .     ..            .     . .
# .______      ___      .__   __.  ________      ___
# |   _  \    /   \     |  \ |  | |       /     /   \
# |  |_)  |  /  ^  \    |   \|  | `---/  /     /  ^  \
# |   ___/  /  /_\  \   |  . `  |    /  /     /  /_\  \
# |  |     /  _____  \  |  |\   |   /  /----./  _____  \
# | _|    /__/     \__\ |__| \__|  /________/__/     \__\

# %%
from hydra import initialize, compose
from omegaconf import OmegaConf as om
from omegaconf import OmegaConf, open_dict
from hydra.core.hydra_config import HydraConfig

# %cd /content/PanzaMail
sys.path.append(os.path.abspath(os.path.join('../src')))


config_dir = "./configs"

with initialize(version_base="1.1", config_path=config_dir):
    cfg = compose(config_name="panza_preparation.yaml")
    OmegaConf.set_struct(cfg, False)
    cfg.writer.llm.name = 'meta-llama/Llama-3.2-3B-Instruct'
    cfg.writer.llm.checkpoint  = 'meta-llama/Llama-3.2-3B-Instruct'
    cfg.panza_workspace = os.getcwd()
    om.resolve(cfg)
    print(cfg)
# Out:
# /content/PanzaMail
# /usr/local/lib/python3.11/dist-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'panza_preparation.yaml': Defaults list is missing `_self_`. See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)
# {'user': {'email_address': 'david_anonymous@xyz.com', 'username': 'david_anonymous', 'data_dir': '/content/PanzaMail/data', 'system_preamble_path': '/content/PanzaMail/prompt_preambles/system_preamble.txt', 'user_preamble_path': '/content/PanzaMail/prompt_preambles/user_preamble.txt', 'rag_preamble_path': '/content/PanzaMail/prompt_preambles/rag_preamble.txt', 'thread_preamble_path': '/content/PanzaMail/prompt_preambles/thread_preamble.txt'}, 'panza_workspace': '/content/PanzaMail', 'checkpoint_dir': '/content/PanzaMail/checkpoints', 'seed': 41, 'embedding_model': 'sentence-transformers/all-mpnet-base-v2', 'model_precision': 'bf16', 'writer': {'llm': {'sampling': {'do_sample': True, 'temperature': 0.7, 'top_k': 50, 'top_p': 0.7, 'max_new_tokens': 1024}, '_target_': 'panza.llm.TransformersLLM', 'name': 'meta-llama/Llama-3.2-3B-Instruct', 'checkpoint': 'meta-llama/Llama-3.2-3B-Instruct', 'device': 'cuda', 'dtype': 'bf16', 'load_in_4bit': False, 'remove_prompt_from_stream': False}, 'prompting': {'_target_': 'panza.prompting.SummarizationPromptBuilder', 'summarization_prompt': 'Summarize the following email that I wrote, in an imperative form, in one or two or maximum three sentences, and make sure to include relevant information, without copying the email content itself. The summary should look like an instruction directing someone to write the same email, and start with Instruction: \nHere is the email text:\n{email}'}, '_target_': 'panza.writer.PanzaWriter'}, 'retriever': {'_target_': 'panza.retriever.FaissRetriever', 'db_path': '/content/PanzaMail/data', 'index_name': 'david_anonymous', 'embedding_model': 'sentence-transformers/all-mpnet-base-v2', 'device': 'cpu'}, 'batch_size': 8, 'email_dump_path': '/content/PanzaMail/data/Sent.mbox', 'cleaned_emails_path': '/content/PanzaMail/data/david_anonymous_clean.jsonl', 'discarded_emails_dir': '/content/PanzaMail/data/david_anonymous/discarded_emails', 'summarized_emails_path': '/content/PanzaMail/data/david_anonymous_clean_summarized.jsonl', 'rag_db_dir': '/content/PanzaMail/data', 'checkpoint': 'microsoft/Phi-3-mini-4k-instruct', 'force_extract_clean_emails': False, 'test_split': 0.0, 'split_type': 'random', 'rag_embedding_chunk_size': 3000, 'rag_embedding_chunk_overlap': 3000, 'rag_embedding_model': 'sentence-transformers/all-mpnet-base-v2', 'number_rag_emails_to_cache_with_train_data': 10}

# %%
import importlib.util

# Path to the file you want to import from
file_path = "/content/PanzaMail/scripts/prepare_data.py"

# Load the module
spec = importlib.util.spec_from_file_location("prepare_data", file_path)
prepare_data = importlib.util.module_from_spec(spec)
spec.loader.exec_module(prepare_data)

# Now you can access the function
rename_config_keys = prepare_data.rename_config_keys
load_documents = prepare_data.load_documents
generate_synthetic_instructions = prepare_data.generate_synthetic_instructions
check_if_file_exists = prepare_data.check_if_file_exists
split_and_write_data = prepare_data.split_and_write_data

# %%
rename_config_keys(cfg)
if not check_if_file_exists(cfg):
  extract_emails(cfg.email_dump_path, cfg.cleaned_emails_path,[cfg.user.email_address], cfg.discarded_emails_dir,)
# Out:
# WARNING:prepare_data:Cleaned email file already exists, using existing file /content/PanzaMail/data/david_anonymous_clean.jsonl. If you want to regenerate use the flag force_extract_clean_emails=true.

# %%
import hydra
from panza import PanzaWriter

writer: PanzaWriter = hydra.utils.instantiate(cfg.writer)
assert isinstance(writer, PanzaWriter), "Failed to instantiate PanzaWriter"
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# Patch for float32 serialization
def json_fallback(obj):
    if isinstance(obj, (np.floating, np.float32, np.float64)):
        return float(obj)
    if isinstance(obj, (np.integer, np.int32, np.int64)):
        return int(obj)
    raise TypeError(f"Object of type {type(obj).__name__} is not JSON serializable")

json._default_encoder = json.JSONEncoder(default=json_fallback)

# %%
documents = load_documents(cfg.cleaned_emails_path)
generate_synthetic_instructions(documents=documents, writer=writer, batch_size=cfg.batch_size, output_path=cfg.summarized_emails_path,)
split_and_write_data(cfg)
create_vector_store(
        os.path.join(cfg.user.data_dir, "train.jsonl"),
        cfg.rag_embedding_chunk_size,
        cfg.rag_embedding_chunk_overlap,
        cfg.rag_db_dir,
        cfg.user.username,
        cfg.rag_embedding_model,
    )

if cfg.number_rag_emails_to_cache_with_train_data > 0:
        prepare_raft_emails(
            os.path.join(cfg.user.data_dir, "train.jsonl"),
            cfg.rag_embedding_model,
            cfg.rag_db_dir,
            cfg.user.username,
            cfg.number_rag_emails_to_cache_with_train_data,
            write_back_to_same_loc=True,
        )
# Out:
# --> # emails = 166
#   0%|          | 0/21 [00:00<?, ?it/s]
# --> Processing batch 1/21
#   5%|▍         | 1/21 [00:23<07:44, 23.22s/it]
# --> Processing batch 2/21
#  10%|▉         | 2/21 [00:45<07:07, 22.49s/it]
# --> Processing batch 3/21
#  14%|█▍        | 3/21 [01:02<06:05, 20.33s/it]
# --> Processing batch 4/21
#  19%|█▉        | 4/21 [01:18<05:13, 18.43s/it]
# --> Processing batch 5/21
#  24%|██▍       | 5/21 [01:34<04:38, 17.43s/it]
# --> Processing batch 6/21
#  29%|██▊       | 6/21 [01:51<04:21, 17.41s/it]
# --> Processing batch 7/21
#  33%|███▎      | 7/21 [02:08<04:02, 17.33s/it]
# --> Processing batch 8/21
#  38%|███▊      | 8/21 [02:23<03:35, 16.56s/it]
# --> Processing batch 9/21
#  43%|████▎     | 9/21 [02:38<03:12, 16.01s/it]
# --> Processing batch 10/21
#  48%|████▊     | 10/21 [03:00<03:16, 17.82s/it]
# --> Processing batch 11/21
#  52%|█████▏    | 11/21 [03:22<03:10, 19.09s/it]
# --> Processing batch 12/21
#  57%|█████▋    | 12/21 [03:36<02:38, 17.59s/it]
# --> Processing batch 13/21
#  62%|██████▏   | 13/21 [03:51<02:13, 16.71s/it]
# --> Processing batch 14/21
#  67%|██████▋   | 14/21 [04:12<02:07, 18.22s/it]
# --> Processing batch 15/21
#  71%|███████▏  | 15/21 [04:27<01:43, 17.19s/it]
# --> Processing batch 16/21
#  76%|███████▌  | 16/21 [04:43<01:23, 16.75s/it]
# --> Processing batch 17/21
#  81%|████████  | 17/21 [05:01<01:09, 17.30s/it]
# --> Processing batch 18/21
#  86%|████████▌ | 18/21 [05:22<00:55, 18.41s/it]
# --> Processing batch 19/21
#  90%|█████████ | 19/21 [05:37<00:34, 17.34s/it]
# --> Processing batch 20/21
#  95%|█████████▌| 20/21 [05:51<00:16, 16.26s/it]
# --> Processing batch 21/21
# 100%|██████████| 21/21 [06:07<00:00, 17.49s/it]
# /content/PanzaMail/src/panza/data_preparation/rag.py:43: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings_model = HuggingFaceEmbeddings(
# Loaded 166 emails.
# Obtained 166 text chunks.
# Creating vector DB...
# Vector DB created in 27.67449402809143 seconds.
# Vector DB index david_anonymous saved to /content/PanzaMail/data.
# --> Reading emails from: /content/PanzaMail/data/train.jsonl
# --> # emails = 166
# Faiss index loaded
#   0%|          | 0/42 [00:00<?, ?it/s]
# --> Processing batch 0/166
#   2%|▏         | 1/42 [00:00<00:28,  1.44it/s]
# --> Processing batch 4/166
#   5%|▍         | 2/42 [00:01<00:29,  1.37it/s]
# --> Processing batch 8/166
#   7%|▋         | 3/42 [00:02<00:25,  1.51it/s]
# --> Processing batch 12/166
#  10%|▉         | 4/42 [00:02<00:25,  1.48it/s]
# --> Processing batch 16/166
#  12%|█▏        | 5/42 [00:03<00:23,  1.58it/s]
# --> Processing batch 20/166
#  14%|█▍        | 6/42 [00:03<00:21,  1.64it/s]
# --> Processing batch 24/166
#  17%|█▋        | 7/42 [00:04<00:21,  1.67it/s]
# --> Processing batch 28/166
#  19%|█▉        | 8/42 [00:05<00:21,  1.58it/s]
# --> Processing batch 32/166
#  21%|██▏       | 9/42 [00:05<00:21,  1.56it/s]
# --> Processing batch 36/166
#  24%|██▍       | 10/42 [00:06<00:20,  1.57it/s]
# --> Processing batch 40/166
#  26%|██▌       | 11/42 [00:07<00:21,  1.45it/s]
# --> Processing batch 44/166
#  29%|██▊       | 12/42 [00:07<00:20,  1.49it/s]
# --> Processing batch 48/166
#  31%|███       | 13/42 [00:08<00:19,  1.52it/s]
# --> Processing batch 52/166
#  33%|███▎      | 14/42 [00:09<00:17,  1.61it/s]
# --> Processing batch 56/166
#  36%|███▌      | 15/42 [00:09<00:16,  1.66it/s]
# --> Processing batch 60/166
#  38%|███▊      | 16/42 [00:10<00:15,  1.71it/s]
# --> Processing batch 64/166
#  40%|████      | 17/42 [00:10<00:13,  1.80it/s]
# --> Processing batch 68/166
#  43%|████▎     | 18/42 [00:11<00:12,  1.89it/s]
# --> Processing batch 72/166
#  45%|████▌     | 19/42 [00:11<00:12,  1.78it/s]
# --> Processing batch 76/166
#  48%|████▊     | 20/42 [00:12<00:12,  1.70it/s]
# --> Processing batch 80/166
#  50%|█████     | 21/42 [00:13<00:12,  1.63it/s]
# --> Processing batch 84/166
#  52%|█████▏    | 22/42 [00:14<00:14,  1.38it/s]
# --> Processing batch 88/166
#  55%|█████▍    | 23/42 [00:14<00:12,  1.50it/s]
# --> Processing batch 92/166
#  57%|█████▋    | 24/42 [00:15<00:11,  1.58it/s]
# --> Processing batch 96/166
#  60%|█████▉    | 25/42 [00:15<00:10,  1.64it/s]
# --> Processing batch 100/166
#  62%|██████▏   | 26/42 [00:16<00:09,  1.72it/s]
# --> Processing batch 104/166
#  64%|██████▍   | 27/42 [00:16<00:08,  1.72it/s]
# --> Processing batch 108/166
#  67%|██████▋   | 28/42 [00:17<00:09,  1.45it/s]
# --> Processing batch 112/166
#  69%|██████▉   | 29/42 [00:18<00:08,  1.47it/s]
# --> Processing batch 116/166
#  71%|███████▏  | 30/42 [00:19<00:08,  1.45it/s]
# --> Processing batch 120/166
#  74%|███████▍  | 31/42 [00:19<00:08,  1.34it/s]
# --> Processing batch 124/166
#  76%|███████▌  | 32/42 [00:20<00:07,  1.39it/s]
# --> Processing batch 128/166
#  79%|███████▊  | 33/42 [00:21<00:06,  1.38it/s]
# --> Processing batch 132/166
#  81%|████████  | 34/42 [00:21<00:05,  1.51it/s]
# --> Processing batch 136/166
#  83%|████████▎ | 35/42 [00:22<00:04,  1.53it/s]
# --> Processing batch 140/166
#  86%|████████▌ | 36/42 [00:22<00:03,  1.67it/s]
# --> Processing batch 144/166
#  88%|████████▊ | 37/42 [00:23<00:03,  1.62it/s]
# --> Processing batch 148/166
#  90%|█████████ | 38/42 [00:24<00:02,  1.73it/s]
# --> Processing batch 152/166
#  93%|█████████▎| 39/42 [00:24<00:01,  1.80it/s]
# --> Processing batch 156/166
#  95%|█████████▌| 40/42 [00:25<00:01,  1.84it/s]
# --> Processing batch 160/166
#  98%|█████████▊| 41/42 [00:25<00:00,  1.83it/s]
# --> Processing batch 164/166
# 100%|██████████| 42/42 [00:25<00:00,  1.62it/s]
# 25.92 seconds to process 166 emails.

# %%
from hydra import initialize, compose
from omegaconf import OmegaConf as om
from omegaconf import OmegaConf, open_dict
from hydra.core.hydra_config import HydraConfig
sys.path.append(os.path.abspath(os.path.join('../src')))

config_dir = "./configs"

with initialize(version_base="1.1", config_path=config_dir):
    cfg = compose(config_name="panza_finetuning.yaml")
    OmegaConf.set_struct(cfg, False)
    cfg.panza_workspace = os.getcwd()
    om.resolve(cfg)
    cfg.preprocessing.model = cfg.finetuning.model_name_or_path
    prompting_config = cfg.preprocessing.prompting

# %%
max_seq_length = 512
dtype = None
load_in_4bit = True
load_in_8bit = False

# %%
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/llama-3-8b-Instruct-bnb-4bit",
    max_seq_length = max_seq_length,
    dtype = dtype,
    full_finetuning = False,
    load_in_4bit = load_in_4bit,
    load_in_8bit = load_in_8bit,
)

model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # rank stabilized LoRA
    loftq_config = None, # LoftQ
)

prompt_builder = hydra.utils.instantiate(prompting_config)
# Out:
# ==((====))==  Unsloth 2025.5.7: Fast Llama patching. Transformers: 4.51.3.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth 2025.5.7 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %%
def panza_preprocessing_function(inputs):
    try:
        prompt_raw = inputs["summary"].split("\n\nInstruction: ")[-1]
        instruction = EmailInstruction(instruction=prompt_raw, thread=inputs.get("thread", []))
        prompt = prompt_builder.build_prompt(instruction)
        conversation = [
            {"role": "user", "content": prompt},
            {"role": "assistant", "content": inputs["email"]},
        ]
        chat_prompt = tokenizer.apply_chat_template(conversation, tokenize=False)
        response_begin_index = chat_prompt.index(inputs["email"].strip())

        prompt = chat_prompt[:response_begin_index]
        response = chat_prompt[response_begin_index:]

        return {
            "prompt": prompt,
            "response": response,
            "text": prompt + response,
        }
    except Exception as e:
        raise ValueError(f"Unable to extract prompt/response from {inputs}") from e

# %%
def get_dataset(filename):
    data = load_dataset(
        path="json",
        data_files={"train":filename},
        split="train",
    )
    data = data.map(panza_preprocessing_function, remove_columns=data.column_names,batched = False)
    return data

train_dataset = get_dataset("./data/train.jsonl")
test_dataset = get_dataset("./data/test.jsonl")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/166 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/166 [00:00<?, ? examples/s]

# %%
trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = train_dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False,
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        num_train_epochs = 7,
        learning_rate = 1e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_torch",
        weight_decay = 0.0,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "none", # Use this for WandB etc
    ),
)

trainer_stats = trainer.train()
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=2):   0%|          | 0/166 [00:00<?, ? examples/s]
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 166 | Num Epochs = 7 | Total steps = 140
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 41,943,040/8,000,000,000 (0.52% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='140' max='140' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [140/140 16:52, Epoch 6/7]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.642700</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.558800</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.532300</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.369400</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.213700</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.994400</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.549200</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.337100</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.307300</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.123600</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.825700</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.633600</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.799800</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.456300</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.314000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.366100</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.141200</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.039700</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.290200</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.093400</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.861400</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.858500</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.290900</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.081900</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.008400</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.922800</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.988500</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.980600</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.863500</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.989100</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.931400</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.956300</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.872500</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.789500</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.221200</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.846400</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.061300</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.980100</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.008500</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.876300</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>1.623000</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.880000</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.951300</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.914900</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.863200</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.738900</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.836500</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.806900</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.840500</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.941100</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.914200</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.684500</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>1.032100</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.658900</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.866200</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.829200</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>1.128400</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.824600</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.769200</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.859200</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>1.677900</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.743900</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.815500</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.658900</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.741000</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.723800</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.744600</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.570600</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.812400</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.861200</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.683800</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.626500</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.692700</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.838200</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.846500</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.798100</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.697900</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.727300</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>0.604600</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.696800</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>1.304100</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.658500</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>0.715600</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.839100</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.509700</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.663500</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>0.619100</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.527000</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.586400</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.563500</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.636900</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>0.899100</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>0.562400</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>0.578200</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.712600</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.626200</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>0.623000</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>0.562900</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.687200</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.633800</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>1.133700</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>0.601400</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>0.479500</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>0.456900</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.499600</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>0.636700</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>0.495000</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>0.435600</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>0.770900</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.588900</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>0.599500</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>0.601500</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>0.477000</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>0.548900</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.662000</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>0.496800</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>0.429200</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>0.549800</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>0.455000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.452600</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>0.800600</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>0.374300</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>0.495900</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>0.458000</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.349200</td>
#     </tr>
#     <tr>
#       <td>126</t

# %%
FastLanguageModel.for_inference(model)
streamer = TextStreamer(tokenizer, skip_prompt=True)
rouge_scores = []
mauve_scores = []
bleu_scores = []
golden_responses = []
panza_responses = []
count = 0
dataset = test_dataset

# %%
def do_compute_metrics(all_responses):
    for response in all_responses:
        response["scores"] = {}
        response["scores"]["BLEU"] = compute_bleu_scores(
            response["panza_responses"], response["golden_responses"]
        )
        response["scores"]["ROUGE"] = compute_rouge_scores(
            response["panza_responses"], response["golden_responses"]
        )
    rouge_categories = all_responses[0]["scores"]["ROUGE"][0].keys()
    aggregate_metrics = {
        "BLEU": np.mean([s for r in all_responses for s in r["scores"]["BLEU"]]),
        "ROUGE": {
                cat: np.mean([s[cat] for r in all_responses for s in r["scores"]["ROUGE"]])
                for cat in rouge_categories
        },
        "MAUVE": compute_mauve_score(
                [r["panza_responses"] for r in all_responses],
                [r["golden_responses"] for r in all_responses],
        ).mauve,
    }
    print("########## Aggregated quality metrics ##########\n")
    print(json.dumps(aggregate_metrics, indent=2))
    return {"responses": all_responses, "aggregate_metrics": aggregate_metrics}

# %%
for x in dataset:
    inputs = tokenizer(x['prompt'], return_tensors="pt",)
    input_ids = inputs["input_ids"].to(model.device)
    attention_mask = inputs["attention_mask"].to(model.device)
    output = model.generate(input_ids, max_new_tokens = 256, attention_mask=attention_mask)
    output_text = tokenizer.decode(output[0], skip_special_tokens=True)
    panza_responses = [re.sub(r"^Subject:.*\n", "", resp, flags=re.IGNORECASE) for resp in panza_responses]
    golden_responses.append(x['response'].rstrip().removesuffix("<|eot_id|>"))
    panza_responses.append(output_text.split("assistant\n")[-1].strip())

panza_responses = [resp.rstrip().removesuffix("<|eotid|>") for resp in panza_responses]
golden_responses = [resp.split("assistant")[-1].strip() for resp in golden_responses]
all_responses = [
    {"panza_responses": [pred], "golden_responses": [gold]}
    for pred, gold in zip(panza_responses, golden_responses)
]
data = {
    "panza_response": panza_responses,
    "golden_response": golden_responses
}

df = pd.DataFrame(data)
do_compute_metrics(all_responses)
# Out:
# Loading tokenizer
# Tokenizing text...
# Loading tokenizer
# Loading model
# Featurizing tokens
# Featurizing p:   0%|          | 0/166 [00:00<?, ?it/s]
# Tokenizing text...
# Featurizing tokens
# Featurizing q:   0%|          | 0/166 [00:00<?, ?it/s]
# seed = 25
# performing clustering in lower dimension = 42
# kmeans time: 0.25 s
# total discretization time: 0.44 seconds
# ########## Aggregated quality metrics ##########
#
# {
#   "BLEU": 0.416107937918011,
#   "ROUGE": {
#     "rouge1_fmeasure": 0.6171970923981035,
#     "rouge1_precision": 0.6396843248821167,
#     "rouge1_recall": 0.6176533339073859,
#     "rouge2_fmeasure": 0.40317841349955064,
#     "rouge2_precision": 0.417258518534791,
#     "rouge2_recall": 0.40222867609686164,
#     "rougeL_fmeasure": 0.5640072697796017,
#     "rougeL_precision": 0.5833571008350475,
#     "rougeL_recall": 0.5642776719956513,
#     "rougeLsum_fmeasure": 0.5640072697796017,
#     "rougeLsum_precision": 0.5833571008350475,
#     "rougeLsum_recall": 0.5642776719956513
#   },
#   "MAUVE": 0.9806815434374475
# }
# {'responses': [{'panza_responses': ['Dear Prof. Aman,\r\n\r\nIt was great to have you at the event!\r\n\r\nCould you please share me with the contact of the person responsible for\r\nthe technical aspects of your cluster?\r\n\r\nI would be very happy to host you at our company in the future.\r\n\r\nBest regards,\r\nDavid'],
#    'golden_responses': ["Dear Prof. Aman,\r\n\r\nIt was great talking to you at the event last week!\r\n\r\nI wanted to ask if you could please share the contact of the person who\r\ndealt with the technical details of your cluster. As I mentioned, we\r\nare  looking to make a similar investment, and it would be really great to\r\nbe able to talk to someone who has already dealt with some of the technical\r\npitfalls.\r\n\r\nSecondly, I would be very happy to host you at our company in the future. Please let\r\nme know if that's the case.\r\n\r\nBest regards,\r\nDavid"],
#    'scores': {'BLEU': [0.2697422206401825],
#     'ROUGE': [{'rouge1_fmeasure': 0.6068965792655945,
#       'rouge1_precision': 0.9166666865348816,
#       'rouge1_recall': 0.4536082446575165,
#       'rouge2_fmeasure': 0.4615384638309479,
#       'rouge2_precision': 0.7021276354789734,
#       'rouge2_recall': 0.34375,
#       'rougeL_fmeasure': 0.565517246723175,
#       'rougeL_precision': 0.8541666865348816,
#       'rougeL_recall': 0.42268040776252747,
#       'rougeLsum_fmeasure': 0.565517246723175,
#       'rougeLsum_precision': 0.8541666865348816,
#       'rougeLsum_recall': 0.42268040776252747}]}},
#   {'panza_responses': ["Dear Tom,\r\n\r\nCould you please reactivate Peter's IT account? He would need it for a\r\ncouple of additional experiments.\r\n\r\nBest regards,\r\nDavid"],
#    'golden_responses': ['Dear Tom,\r\n\r\nWould it be possible to "resurrect" Peter\'s IT account? He would need to run\r\nsome additional experiments.\r\n\r\nBest regards,\r\nDavid'],
#    'scores': {'BLEU': [0.5172334909439087],
#     'ROUGE': [{'rouge1_fmeasure': 0.6363636255264282,
#       'rouge1_precision': 0.6363636255264282,
#       'rouge1_recall': 0.6363636255264282,
#       'rouge2_fmeasure': 0.4761904776096344,
#       'rouge2_precision': 0.4761904776096344,
#       'rouge2_recall': 0.4761904776096344,
#       'rougeL_fmeasure': 0.5909090638160706,
#       'rougeL_precision': 0.5909090638160706,
#       'rougeL_recall': 0.5909090638160706,
#       'rougeLsum_fmeasure': 0.5909090638160706,
#       'rougeLsum_precision': 0.5909090638160706,
#       'rougeLsum_recall': 0.5909090638160706}]}},
#   {'panza_responses': ['Dear Archie,\r\n\r\nThanks for your patience, I have finally submitted the proposal.\r\n\r\nBest regards,\r\nDavid'],
#    'golden_responses': ['Thanks Archie! With some delay, I have submitted a proposal.'],
#    'scores': {'BLEU': [0.1422577202320099],
#     'ROUGE': [{'rouge1_fmeasure': 0.47999998927116394,
#       'rouge1_precision': 0.4000000059604645,
#       'rouge1_recall': 0.6000000238418579,
#       'rouge2_fmeasure': 0.08695652335882187,
#       'rouge2_precision': 0.0714285746216774,
#       'rouge2_recall': 0.1111111119389534,
#       'rougeL_fmeasure': 0.4000000059604645,
#       'rougeL_precision': 0.3333333432674408,
#       'rougeL_recall': 0.5,
#       'rougeLsum_fmeasure': 0.4000000059604645,
#       'rougeLsum_precision': 0.3333333432674408,
#       'rougeLsum_recall': 0.5}]}},
#   {'panza_responses': ['Dear Stephan,\r\n\r\nThank you for the invitation, I would have loved to come to Paris in December,\r\nbut unfortunately I already have travel commitments in New York on the 9th.\r\n\r\nMaybe we can give an online talk instead?\r\n\r\nBest regards,\r\nDavid'],
#    'golden_responses': ['Dear Stephan,\r\n\r\nThank you so much for the invitation. Unfortunately I cannot be physically\r\nin Paris in December, since I am traveling,\r\nand am supposed to be in New York on December 9th.\r\n\r\nIf it helps, I would be happy to give an online talk if possible.\r\n\r\nBest regards,\r\nDavid'],
#    'scores': {'BLEU': [0.3808695077896118],
#     'ROUGE': [{'rouge1_fmeasure': 0.6153846383094788,
#       'rouge1_precision': 0.6829268336296082,
#       'rouge1_recall': 0.5600000023841858,
#       'rouge2_fmeasure': 0.3820224702358246,
#       'rouge2_precision': 0.42500001192092896,
#       'rouge2_recall': 0.3469387888908386,
#       'rougeL_fmeasure': 0.5274725556373596,
#       'rougeL_precision': 0.5853658318519592,
#       'rougeL_recall': 0.47999998927116394,
#       'rougeLsum_fmeasure': 0.5274725556373596,
#       'rougeLsum_precision': 0.5853658318519592,
#       'rougeLsum_recall': 0.47999998927116394}]}},
#   {'panza_responses': ['Dear James,\r\n\r\nI hope all is well with you. I wanted to follow up on an email I sent\r\na few months ago regarding the possibility of applying sparse\r\nalgorithms to efficient cloud computing. I thought you might find this\r\ninteresting.\r\n\r\nI attached two recent papers, one on sparse algorithms for matrix\r\nmultiplication and another on using sparse approximations for\r\naccelerating machine learning computations.\r\n\r\nPlease let me know if you would like to explore this area further. You\r\nmight find that some of your methods can be adapted to this new setting.\r\n\r\nBest regards,\r\nDavid'],
#    'golden_responses': ["Dear James,\r\n\r\nI hope you don't mind me contacting you out of the blue--we've exchanged\r\nsome emails a few years ago regarding efficient cloud algorithms.\r\n\r\nI am getting in touch since I wanted to mention an emerging research\r\ndirection which you may find interesting. Specifically, there are a few interesting recent results on sparse .\r\nFor example, please see these two recent papers:\r\n\r\n1. https://arxiv.org/abs/2301.00774 \r\n\r\n2. https://arxiv.org/abs/2306.11695\r\n\r\nI wanted to ask if you'd be interested in having a closer look at this, and\r\nin particular if any of your methods would port to this setting.\r\n\r\nBest regards,\r\nDavid"],
#    'scores': {'BLEU': [0.271303653717041],
#     'ROUGE': [{'rouge1_fmeasure': 0.5,
#       'rouge1_precision': 0.5052631497383118,
#       'rouge1_recall': 0.49484536051750183,
#       'rouge2_fmeasure': 0.17894737422466278,
#       'rouge2_precision': 0.1808510571718216,
#       'rouge2_recall': 0.1770833283662796,
#       'rougeL_fmeasure': 0.3229166567325592,
#       'rougeL_precision': 0.3263157904148102,
#       'rougeL_recall': 0.3195876181125641,
#       'rougeLsum_fmeasure': 0.3229166567325592,
#       'rougeLsum_precision': 0.3263157904148102,
#       'rougeLsum_recall': 0.3195876181125641}]}},
#   {'panza_responses': ['Hi,\r\n\r\nI am attaching the contract, but please note that the email address in the contract is\r\nincorrect.\r\n\r\nCould you please confirm the car check-out, and when do you plan to return the deposit?\r\n\r\nBest,\r\nDavid'],
#    'golden_responses': ['Hello,\r\n\r\nI have a question regarding the contract attached. Unfortunately, the email\r\naddress in the contract is incorrect. Could you\r\nplease send me the confirmation of the car check-out, and let me know when\r\nthe deposit would be returned to me?\r\n\r\nBest regards,\r\nDavid'],
#    'scores': {'BLEU': [0.41073960065841675],
#     'ROUGE': [{'rouge1_fmeasure': 0.6000000238418579,
#       'rouge1_precision': 0.6666666865348816,
#       'rouge1_recall': 0.5454545617103577,
#       'rouge2_fmeasure': 0.38461539149284363,
#       'rouge2_precision': 0.4285714328289032,
#       'rouge2_recall': 0.3488371968269348,
#       'rougeL_fmeasure': 0.574999988079071,
#       'rougeL_precision': 0.6388888955116272,
#       'rougeL_recall': 0.5227272510528564,
#       'rougeLsum_fmeasure': 0.574999988079071,
#       'rougeLsum_precision': 0.6388888955116272,
#       'rougeLsum_recall': 0.5227272510528564}]}},
#   {'panza_responses': ['Dear David,\r\n\r\nI hope all is well. I was wondering if I could ask you to do an\r\nemergency-mode code review? I have attached the code, and it would be\r\ngreat if you could take a look in the next couple of weeks.\r\n\r\nMany thanks!\r\nDavid'],
#    'golden_responses': ['Dear David,\r\n\r\nI was wondering if I could ask you for an "emergency-mode" code review (see attached). Specifically, it would be\r\ngreat if you could have a look at it in the next couple of weeks.\r\n\r\nI\'d really appreciate it if you can make it; please let me know.\r\n\r\nCheers,\r\nDavid'],
#    'scores': {'BLEU': [0.5160040855407715],
#     'ROUGE': [{'rouge1_fmeasure': 0.6597937941551208,
#       'rouge1_precision': 0.695652186870575,
#       'rouge1_recall': 0.6274510025978088,
#       'rouge2_fmeasure': 0.5052631497383118,
#       'rouge2_precision': 0.5333333611488342,
#       'rouge2_recall': 0.47999998927116394,
#       'rougeL_fmeasure': 0.6391752362251282,
#       'rougeL_precision': 0.6739130616188049,
#       'rougeL_recall': 0.6078431606292725,
#       'rougeLsum_fmeasure': 0.6391752362251282,
#       'rougeLsum_precision': 0.6739130616188049,
#       'rougeLsum_recall': 0.6078431606292725}]}},
#   {'panza_responses': ["Thanks, I'm glad I got to make the decision. I will attend the\r\norientation on November 15th.\r\n\r\nBest,\r\nDavid"],
#    'golden_responses': ['Thank you, in that case, I will attend the November 15th orientation.\r\n\r\nBest,\r\nDavid'],
#    'scores': {'BLEU': [0.31550267338752747],
#     'ROUGE': [{'rouge1_fmeasure': 0.5454545617103577,
#       'rouge1_precision': 0.4736842215061188,
#       'rouge1_recall': 0.6428571343421936,
#       'rouge2_fmeasure': 0.32258063554763794,
#       'rouge2_precision': 0.2777777910232544,
#       'rouge2_recall': 0.38461539149284363,
#       'rougeL_fmeasure': 0.4848484992980957,
#       'rougeL_precision': 0.42105263471603394,
#       'rougeL_recall': 0.5714285969734192,
#       'rougeLsum_fmeasure': 0.4848484992980957,
#       'rougeLsum_precision': 0.42105263471603394,
#       'rougeLsum_recall': 0.5714285969734192}]}},
#   {'panza_responses': ["Dear Kevin,\r\n\r\nI am also sending you a message since my application is still under\r\nconsideration. I can imagine it's not easy to schedule meetings since\r\nmany people are out of the office.\r\n\r\nBest regards,\r\nDavid"],
#    'golden_responses': ['Dear Kevin,\r\n\r\nAs I said in my last communications, your application is still under\r\nconsideration; although I am trying my best, it is unfortunately extremely\r\ndifficult to schedule meetings these days, with people out of the office.\r\n\r\nBest regards,\r\nDavid'],
#    'scores': {'BLEU': [0.4108051061630249],
#     'ROUGE': [{'rouge1_fmeasure': 0.5789473652839661,
#       'rouge1_precision': 0.6111111044883728,
#       'rouge1_recall': 0.550000011920929,
#       'rouge2_fmeasure': 0.37837839126586914,
#       'rouge2_precision': 0.4000000059604645,
#       'rouge2_recall': 0.3589743673801422,
#       'rougeL_fmeasure': 0.5526315569877625,
#       'rougeL_precision': 0.5833333134651184,
#       'rougeL_recall': 0.5249999761581421,
#       'rougeLsum_fmeasure': 0.5526315569877625,
#       'rougeLsum_precision': 0.5833333134651184,
#       'rougeLsum_recall': 0.5249999761581421}]}},
#   {'panza_responses': ['Dear Frank,\r\n\r\nI am really sorry about this, but it seems that there was no way to\r\nknow about it. I am withdrawing the request due to necessity, and I\r\nhope this gets resolved soon.\r\n\r\nBest regards,\r\nDavid'],
#    'golden_responses': ['Dear Frank,\r\n\r\nI am really sorry about this, this is really not what we want to happen,\r\nand as you can imagine I was not aware of this. I will withdraw the request\r\ntoday, and hopefully this will get resolved soon.\r\n\r\nBest regards,\r\nDavid'],
#    'scores': {'BLEU': [0.3498697280883789],
#     'ROUGE': [{'rouge1_fmeasure': 0.5121951103210449,
#       'rouge1_precision': 0.5526315569877625,
#       'rouge1_recall': 0.47727271914482117,
#       'rouge2_fmeasure': 0.30000001192092896,
#       'rouge2_precision': 0.3243243098258972,
#       'rouge2_recall': 0.27906978130340576,
#       'rougeL_fmeasure': 0.46341463923454285,
#       'rougeL_precision': 0.5,
#       'rougeL_recall': 0.4318181872367859,
#       'rougeLsum_fmeasure': 0.46341463923454285,
#       'rougeLsum_precision': 0.5,
#       'rougeLsum_recall': 0.4318181872367859}]}},
#   {'panza_responses': ['Hi,\r\n\r\nUnfortunately, the storage migration issue has caused widespread application\r\ncrashes across all services, which is not great.\r\n\r\nBest,\r\nDavid'],
#    'golden_responses': ["Yes, this seems to have been connected with the storage migration. I can\r\nconfirm that everyone's applications have crashed, across all services, which is not\r\ngreat.\r\n\r\nBest,\r\nDavid"],
#    'scores': {'BLEU': [0.36086738109588623],
#     'ROUGE': [{'rouge1_fmeasure': 0.5,
#       'rouge1_precision': 0.6000000238418579,
#       'rouge1_recall': 0.4285714328289032,
#       'rouge2_fmeasure': 0.43478259444236755,
#       'rouge2_precision': 0.5263158082962036,
#       'rouge2_recall': 0.37037035822868347,
#       'rougeL_fmeasure': 0.5,
#       'rougeL_precision': 0.6000000238418579,
#       'rougeL_recall': 0.4285714328289032,
#       'rougeLsum_fmeasure': 0.5,
#       'rougeLsum_precision': 0.6000000238418579,
#       'rougeLsum_recall': 0.4285714328289032}]}},
#   {'panza_responses': ["Hi IT,\r\n\r\nI was wondering if you could look into this? Servers and applications\r\nhave been restarted suddenly, and we were wondering what's going on.\r\n\r\nBest,\r\nDavid"],
#    'golden_responses': ["Dear IT,\r\n\r\nLooks like our servers were restarted, and everyone's applications are restarted. Could\r\nyou please let us know what is going on?\r\n\r\nBest regards,\r\nDavid"],
#    'scores': {'BLEU': [0.18508538603782654],
#     'ROUGE': [{'rouge1_fmeasure': 0.4528301954269409,
#       'rouge1_precision': 0.4444444477558136,
#       'rouge1_recall': 0.4615384638309479,
#       'rouge2_fmeasure': 0.0784313753247261,
#       'rouge2_precision': 0.07692307978868484,
#       'rouge2_recall': 0.07999999821186066,
#       'rougeL_fmeasure': 0.3396226465702057,
#       'rougeL_precision': 0.3333333432674408,
#       'rougeL_recall': 0.3461538553237915,
#       'rougeLsum_fmeasure': 0.3396226465702057,
#       'rougeLsum_precision': 0.3333333432674408,
#       'rougeLsum_recall': 0.3461538553237915}]}},
#   {'panza_responses': ["Hi,\r\n\r\nI will be traveling tomorrow, so let's schedule the meeting for Wednesday\r\nor Thursday, in the early afternoon, and I can send you a Zoom link.\r\n\r\nBest,\r\nDavid"],
#    'golden_responses': ['Hi,\r\n\r\nI am traveling tomorrow, but we could meet on Wednesday or Thursday in the\r\nearly afternoon your time.\r\n\r\nBest,\r\nDavid'],
#    'scores': {'BLEU': [0.3449524939060211],
#     'ROUGE': [{'rouge1_fmeasure': 0.5199999809265137,
#       'rouge1_precision': 0.4482758641242981,
#       'rouge1_recall': 0.6190476417541504,
#       'rouge2_fmeasure': 0.375,
#       'rouge2_precision': 0.3214285671710968,
#       'rouge2_recall': 0.44999998807907104,
#       'rougeL_fmeasure': 0.5199999809265137,
#       'rougeL_precision': 0.4482758641242981,
#       'rougeL_recall': 0.6190476417541504,
#       'rougeLsum_fmeasure': 0.5199999809265137,
#       'rougeLsum_precision': 0.4482758641242981,
#       'rougeLsum_recall': 0.6190476417541504}]}},
#   {'panza_responses': ["Hi,\r\n\r\nMany thanks for having a look at the slides, please let me know what you\r\nthink. Also, please feel free to add your pictures next to your names in the slides,\r\nbut no need to do so if you don't want to.\r\n\r\nCheers,\r\nDavid"],
#    'golden_responses': ['Thanks, I did a pass over the slides and made some minor changes.\r\nPlease have a look and let me know what you think. Also, it would be nice\r\nif you add your pictures next to your names (but this is not obligatory).\r\n\r\nCheers,\r\nDavid'],
#    'scores': {'BLEU': [0.41835644841194153],
#     'ROUGE': [{'rouge1_fmeasure': 0.5555555820465088,
#       'rouge1_precision': 0.5555555820465088,
#       'rouge1_recall': 0.5555555820465088,
#       'rouge2_fmeasure': 0.3636363744735718,
#       'rouge2_precision': 0.3636363744735718,
#       'rouge2_recall': 0.3636363744735718,
#       'rougeL_fmeasure': 0.4888888895511627,
#       'rougeL_precision': 0.4888888895511627,
#       'rougeL_recall': 0.4888888895511627,
#       'rougeLsum_fmeasure': 0.4888888895511627,
#       'rougeLsum_precision': 0.4888888895511627,
#       'rougeLsum_recall': 0.4888888895511627}]}},
#   {'panza_responses': ['Hi,\r\n\r\nI am really sorry for the delay. I have been traveling for the past week.\r\nIn case you would like to see a better version, I can try to do the following:\r\n\r\n- Compress the document with graphs instead of tables (I can do this tomorrow).\r\n\r\n- Expand the executive summary a bit, with the intention of writing a\r\n   more opinionated introduction that summarizes the document and provides\r\n   your opinion on what should be done.\r\n\r\nBest regards,\r\nDavid'],
#    'golden_responses': ['Hi,\r\n\r\nSorry for the delay (due to travel).\r\n\r\nI would say that two things would be great to add:\r\n\r\n   1. A general pass to slightly compress the document and make it more\r\n   readable, perhaps generating a few graphs instead of tables? (ChatGPT could\r\n   help with the graph generation for instance.)\r\n   2. The executive summary could be expanded a bit, as an introduction,\r\n   and be a bit more opinionated: specifically, you could try to give a\r\n   synopsis of the document (here, graphs might help instead of tables, which\r\n   can be provided later) and give _your_ opinion about what should be done?\r\n\r\nBest regards,\r\nDavid'],
#    'scores': {'BLEU': [0.2763923406600952],
#     'ROUGE': [{'rouge1_fmeasure': 0.5111111402511597,
#       'rouge1_precision': 0.5974025726318359,
#       'rouge1_recall': 0.446601927280426,
#       'rouge2_fmeasure': 0.2584269642829895,
#       'rouge2_precision': 0.30263158679008484,
#       'rouge2_recall': 0.22549019753932953,
#       'rougeL_fmeasure': 0.41111111640930176,
#       'rougeL_precision': 0.48051947355270386,
#       'rougeL_recall': 0.35922330617904663,
#       'rougeLsum_fmeasure': 0.41111111640930176,
#       'rougeLsum_precision': 0.48051947355270386,
#       'rougeLsum_recall': 0.35922330617904663}]}},
#   {'panza_responses': ["Yes, this is great! I've been playing around with a template, and I wanted to\r\nask if you could input your preferred version of the report and I can give some\r\nfeedback by November 1st?\r\n\r\nDavid"],
#    'golden_responses': ["That's great! I have shared a template.\r\n\r\nCould you please plug in the version of the report you would like to\r\npublish, and I will provide some feedback?\r\n\r\nThe deadline is around November 1st.\r\n\r\nBest regards,\r\nDavid"],
#    'scores': {'BLEU': [0.2904413044452667],
#     'ROUGE': [{'rouge1_fmeasure': 0.5479452013969421,
#       'rouge1_precision': 0.5555555820465088,
#       'rouge1_recall': 0.5405405163764954,
#       'rouge2_fmeasure': 0.19718310236930847,
#       'rouge2_precision': 0.20000000298023224,
#       'rouge2_recall': 0.1944444477558136,
#       'rougeL_fmeasure': 0.4109589159488678,
#       'rougeL_precision': 0.4166666567325592,
#       'rougeL_recall': 0.4054054021835327,
#       'rougeLsum_fmeasure': 0.4109589159488678,
#       'rougeLsum_precision': 0.4166666567325592,
#       'rougeLsum_recall': 0.4054054021835327}]}},
#   {'panza_responses': ["Hi Larry,\r\n\r\nI had a look at your report, and it's really nice. I was wondering if you\r\nand Taylor would be willing to contribute a version of it to the monthly newsletter,\r\nwith some editing and focusing on specific questions.\r\n\r\nBest,\r\nDavid"],
#    'golden_responses': ['Hi Larry,\r\n\r\nI had a look at your report, and have found it very interesting. Would you\r\nand Taylor be willing to contribute a version of it to the our monthly newsletter?\r\nThis would require a bit of editing/reformatting, and maybe focusing on a\r\nfew specific questions.\r\n\r\nBest regards,\r\nDavid'],
#    'scores': {'BLEU': [0.5346300005912781],
#     'ROUGE': [{'rouge1_fmeasure': 0.7096773982048035,
#       'rouge1_precision': 0.7674418687820435,
#       'rouge1_recall': 0.6600000262260437,
#       'rouge2_fmeasure': 0.5274725556373596,
#       'rouge2_precision': 0.5714285969734192,
#       'rouge2_recall': 0.4897959232330322,
#       'rougeL_fmeasure': 0.6881720423698425,
#       'rougeL_precision': 0.7441860437393188,
#       'rougeL_recall': 0.6399999856948853,
#       'rougeLsum_fmeasure': 0.6881720423698425,
#       'rougeLsum_precision': 0.7441860437393188,
#       'rougeLsum_recall': 0.6399999856948853}]}},
#   {'panza_responses': ['Dear Patent Office,\r\n\r\nA gentle reminder about this question.\r\n\r\nBest,\r\nDavid'],
#    'golden_responses': ['Dear Patent Office,\r\n\r\nA gentle reminder regarding this question.\r\n\r\nBest,\r\nDavid'],
#    'scores': {'BLEU': [0.8122957348823547],
#     'ROUGE': [{'rouge1_fmeasure': 0.9090909361839294,
#       'rouge1_precision': 0.9090909361839294,
#       'rouge1_recall': 0.9090909361839294,
#       'rouge2_fmeasure': 0.800000011920929,
#       'rouge2_precision': 0.800000011920929,
#       'rouge2_recall': 0.800000011920929,
#       'rougeL_fmeasure': 0.9090909361839294,
#       'rougeL_precision': 0.9090909361839294,
#       'rougeL_recall': 0.9090909361839294,
#       'rougeLsum_fmeasure': 0.9090909361839294,
#       'rougeLsum_precision': 0.9090909361839294,
#       'rougeLsum_recall': 0.9090909361839294}]}},
#   {'panza_responses': ["Yes, that's correct. We would be happy to cover the train tickets from/to Riga\r\nfor the 15th and 16th.\r\n\r\nDavid"],
#    'golden_responses': ['Yes, 15th and 16th would be perfect, and I am happy to cover the train\r\ntickets from/to Riga.\r\n\r\nDavid'],
#    'scores': {'BLEU': [0.5936703681945801],
#     'ROUGE': [{'rouge1_fmeasure': 0.7692307829856873,
#       'rouge1_precision': 0.75,
#       'rouge1_recall': 0.7894737124443054,
#       'rouge2_fmeasure': 0.5405405163764954,
#       'rouge2_precision': 0.5263158082962036,
#       'rouge2_recall': 0.5555555820465088,
#       'rougeL_fmeasure': 0.6153846383094788,
#       'rougeL_precision': 0.6000000238418579,
#       'rougeL_recall': 0.6315789222717285,
#       'rougeLsum_fmeasure': 0.6153846383094788,
#       'rougeLsum_precision': 0.6000000238418579,
#       'rougeLsum_recall': 0.6315789222717285}]}},
#   {'panza_responses': ['Dear Tom,\r\n\r\nI wanted to mention that an early version of our work has been released on arXiv: https://arxiv.org/abs/123.456\r\n(The code will be available later this week.)\r\n\r\nAny comments are very much appreciated.\r\n\r\nBest regards,\r\nDavid'],
#    'golden_responses': ['Hi Tom,\r\n\r\nJust wanted to mention that we released an early version of our work here:\r\nhttps://arxiv.org/abs/123.456\r\n(Code is coming later this week.)\r\n\r\nAny comments are more than welcome.\r\n\r\nBest,\r\nDavid'],
#    'scores': {'BLEU': [0.45954352617263794],
#     'ROUGE': [{'rouge1_fmeasure': 0.6567164063453674,
#       'rouge1_precision': 0.6111111044883728,
#       'rouge1_recall': 0.7096773982048035,
#       'rouge2_fmeasure': 0.4000000059604645,
#       'rouge2_precision': 0.37142857909202576,
#       'rouge2_recall': 0.4333333373069763,
#       'rougeL_fmeasure': 0.6268656849861145,
#       'rougeL_precision': 0.5833333134651184,
#       'rougeL_recall': 0.6774193644523621,
#       'rougeLsum_fmeasure': 0.6268656849861145,
#       'rougeLsum_precision': 0.5833333134651184,
#       'rougeLsum_recall': 0.6774193644523621}]}},
#   {'panza_responses': ['Dear Jin,\r\n\r\nAre you in the office either on Wednesday or Thursday? I would love to\r\nmeet you in person.\r\n\r\nBest,\r\nDavid'],
#    'golden_responses': ['Hi Jin,\r\n\r\nAre you in the office this Wednesday or Thursday? Would be great to finally\r\nmeet.\r\n\r\nBest,\r\nDavid'],
#    'scores': {'BLEU': [0.4585742652416229],
#     'ROUGE': [{'rouge1_fmeasure': 0.6829268336296082,
#       'rouge1_precision': 0.6363636255264282,
#       'rouge1_recall': 0.7368420958518982,
#       'rouge2_fmeasure': 0.41025641560554504,
#       'rouge2_precision': 0.380952388048172,
#       'rouge2_recall': 0.4444444477558136,
#       'rougeL_fmeasure': 0.6829268336296082,
#       'rougeL_precision': 0.6363636255264282,
#       'rougeL_recall': 0.7368420958518982,
#       'rougeLsum_fmeasure': 0.6829268336296082,
#       'rougeLsum_precision': 0.6363636255264282,
#       'rougeLsum_recall': 0.7368420958518982}]}},
#   {'panza_responses': ["Dear Jin,\r\n\r\nI am really sorry, but I cannot make it to the office tomorrow. I am traveling\r\nin the area for a few more weeks, and I don't see the need to come back.\r\nFor the time being, we could have a zoom call, and I would be happy to meet\r\nin person in mid-June.\r\n\r\nBest regards,\r\nDavid"],
#    'golden_responses': ["Hi Jin,\r\n\r\nI'm really sorry, but I won't be able to make it to the office tomorrow. Since\r\nI'm traveling this weekend, I'm afraid we'll have to meet in\r\nperson when I'm back in mid-June. Please let me know if you'd like to\r\nhave a zoom call in the meanwhile, I'd be happy to do that.\r\n\r\nBest,\r\nDavid"],
#    'scores': {'BLEU': [0.3642496168613434],
#     'ROUGE': [{'rouge1_fmeasure': 0.5128205418586731,
#       'rouge1_precision': 0.508474588394165,
#       'rouge1_recall': 0.517241358757019,
#       'rouge2_fmeasure': 0.313043475151062,
#       'rouge2_precision': 0.3103448152542114,
#       'rouge2_recall': 0.31578946113586426,
#       'rougeL_fmeasure': 0.39316239953041077,
#       'rougeL_precision': 0.38983049988746643,
#       'rougeL_recall': 0.3965517282485962,
#       'rougeLsum_fmeasure': 0.39316239953041077,
#       'rougeLsum_precision': 0.38983049988746643,
#       'rougeLsum_recall': 0.3965517282485962}]}},
#   {'panza_responses': ["Hi both,\r\n\r\nI'm fairly available in the afternoons of next week, except for Monday\r\nand Friday, so please feel free to suggest a time slot.\r\n\r\nBest,\r\nDavid"],
#    'golden_responses': ["Hi both,\r\n\r\nI'm fairly available in the afternoons next week, except for Monday and\r\nFriday, so please feel free to suggest a slot.\r\n\r\nBest,\r\nDavid"],
#    'scores': {'BLEU': [0.8615286946296692],
#     'ROUGE': [{'rouge1_fmeasure': 0.9615384340286255,
#       'rouge1_precision': 0.9259259104728699,
#       'rouge1_recall': 1.0,
#       'rouge2_fmeasure': 0.8799999952316284,
#       'rouge2_precision': 0.8461538553237915,
#       'rouge2_recall': 0.9166666865348816,
#       'rougeL_fmeasure': 0.9615384340286255,
#       'rougeL_precision': 0.9259259104728699,
#       'rougeL_recall': 1.0,
#       'rougeLsum_fmeasure': 0.9615384340286255,
#       'rougeLsum_precision': 0.9259259104728699,
#       'rougeLsum_recall': 1.0}]}},
#   {'panza_responses': ["Thank you for the invitation, I'd be delighted to give a talk at the\r\nworkshop.\r\n\r\nBest regards,\r\nDavid"],
#    'golden_responses': ['Thank you for the invitation, I would be happy to give a talk at the\r\nworkshop.\r\n\r\nBest regards,\r\nDavid'],
#    'scores': {'BLEU': [0.7607998847961426],
#     'ROUGE': [{'rouge1_fmeasure': 0.8648648858070374,
#       'rouge1_precision': 0.8888888955116272,
#       'rouge1_recall': 0.8421052694320679,
#       'rouge2_fmeasure': 0.7428571581840515,
#       'rouge2_precision': 0.7647058963775635,
#       'rouge2_recall': 0.7222222089767456,
#       'rougeL_fmeasure': 0.8648648858070374,
#       'rougeL_precision': 0.8888888955116272,
#       'rougeL_recall': 0.8421052694320679,
#       'rougeLsum_fmeasure': 0.8648648858070374,
#       'rougeLsum_precision': 0.8888888955116272,
#       'rougeLsum_recall': 0.8421052694320679}]}},
#   {'panza_responses': ['OK, I will be extremely busy for the next 10 days or so, and will set a reminder.\r\nIs this OK?\r\n\r\nDavid'],
#    'golden_responses': ["Sure, will do. We are extremely busy for the next 10 days or\r\nso, but I'll set a reminder. Is that OK?\r\n\r\nBest,\r\nDavid"],
#    'scores': {'BLEU': [0.5481594204902649],
#     'ROUGE': [{'rouge1_fmeasure': 0.695652186870575,
#       'rouge1_precision': 0.7272727489471436,
#       'rouge1_recall': 0.6666666865348816,
#       'rouge2_fmeasure': 0.5,
#       'rouge2_precision': 0.523809552192688,
#       'rouge2_recall': 0.47826087474823,
#       'rougeL_fmeasure': 0.695652186870575,
#       'rougeL_precision': 0.7272727489471436,
#       'rougeL_recall': 0.6666666865348816,
#       'rougeLsum_fmeasure': 0.695652186870575,
#       'rougeLsum_precision': 0.7272727489471436,
#       'rougeLsum_recall': 0.6666666865348816}]}},
#   {'panza_responses': ["Hi,\r\n\r\nCould you please let me know when you're not using the servers for an\r\nextended period of time?\r\n\r\nAlternatively, I could give you a key to grant yourself permission to\r\nsuspend the server.\r\n\r\nBest,\r\nDavid"],
#    'golden_responses': ["Hi,\r\n\r\nCould you please let me know when you're not using the servers for extended\r\nperiods of time?\r\n\r\nAlternatively, please share a key so I can give you permissions to\r\nsuspend it yourself.\r\n\r\nDavid"],
#    'scores': {'BLEU': [0.5925664901733398],
#     'ROUGE': [{'rouge1_fmeasure': 0.7714285850524902,
#       'rouge1_precision': 0.75,
#       'rouge1_recall': 0.7941176295280457,
#       'rouge2_fmeasure': 0.529411792755127,
#       'rouge2_precision': 0.5142857432365417,
#       'rouge2_recall': 0.5454545617103577,
#       'rougeL_fmeasure': 0.6857143044471741,
#       'rougeL_precision': 0.6666666865348816,
#       'rougeL_recall': 0.7058823704719543,
#       'rougeLsum_fmeasure': 0.6857143044471741,
#       'rougeLsum_precision': 0.6666666865348816,
#       'rougeLsum_recall': 0.7058823704719543}]}},
#   {'panza_responses': ["Sounds good, let's do that. I think this should help with efficiency a lot.\r\nWe can share a Google Doc to centralize the results.\r\n\r\nBest regards,\r\nDavid"],
#    'golden_responses': ["OK, I think that's reasonable. How about we try to keep everything more efficient and see if that recovers better for now?\r\n\r\nBy the way, it would be better to put all results in a shared Google Doc,\r\nrather than sending them around.\r\n\r\nBest regards,\r\nDavid"],
#    'scores': {'BLEU': [0.11098171025514603],
#     'ROUGE': [{'rouge1_fmeasure': 0.3561643958091736,
#       'rouge1_precision': 0.48148149251937866,
#       'rouge1_recall': 0.28260868787765503,
#       'rouge2_fmeasure': 0.11267605423927307,
#       'rouge2_precision': 0.1538461595773697,
#       'rouge2_recall': 0.08888889104127884,
#       'rougeL_fmeasure': 0.24657534062862396,
#       'rougeL_precision': 0.3333333432674408,
#       'rougeL_recall': 0.19565217196941376,
#       'rougeLsum_fmeasure': 0.24657534062862396,
#       'rougeLsum_precision': 0.3333333432674408,
#       'rougeLsum_recall': 0.19565217196941376}]}},
#   {'panza_responses': ['Hi,\r\n\r\nI talked to him, and he would rather take the course next year since he\r\nalready covered most of the material.\r\n\r\nBest,\r\nDavid'],
#    'golden_responses': ["Hi,\r\n\r\nI've talked to him, and it looks like he would really prefer to take the course \r\nnext year, since he's already covered a lot of the material.\r\n\r\nBest,\r\nDavid"],
#    'scores': {'BLEU': [0.5122618079185486],
#     'ROUGE': [{'rouge1_fmeasure': 0.7407407164573669,
#       'rouge1_precision': 0.8333333134651184,
#       'rouge1_recall': 0.6666666865348816,
#       'rouge2_fmeasure': 0.5384615659713745,
#       'rouge2_precision': 0.6086956262588501,
#       'rouge2_recall': 0.48275861144065857,
#       'rougeL_fmeasure': 0.7407407164573669,
#       'rougeL_precision': 0.8333333134651184,
#       'rougeL_recall': 0.6666666865348816,
#       'rougeLsum_fmeasure': 0.7407407164573669,
#       'rougeLsum_precision': 0.8333333134651184,
#       'rougeLsum_recall': 0.6666666865348816}]}},
#   {'panza_responses': ["Dear Jeannie,\r\n\r\nThanks for the monitor, it's great!\r\n\r\nBy the way, I wanted to ask if you could do something for me. I've been trying\r\nto get into the conference room this afternoon, but I don't have an ID that\r\nworks after hours. Do you have any suggestions?\r\n\r\nBest regards,\r\nDavid"],
#    'golden_responses': ["Dear Jeannie,\r\n\r\nThanks again for the monitor!\r\nI noticed that unfortunately my ID doesn't give me access to the conference room after hours. Any chance I can get this fixed?\r\n\r\nBest,\r\nDavid"],
#    'scores': {'BLEU': [0.20793840289115906],
#     'ROUGE': [{'rouge1_fmeasure': 0.5301204919815063,
#       'rouge1_precision': 0.4313725531101227,
#       'rouge1_recall': 0.6875,
#       'rouge2_fmeasure': 0.17283950746059418,
#       'rouge2_precision': 0.14000000059604645,
#       'rouge2_recall': 0.22580644488334656,
#       'rougeL_fmeasure': 0.40963855385780334,
#       'rougeL_precision': 0.3333333432674408,
#       'rougeL_recall': 0.53125,
#       'rougeLsum_fmeasure': 0.40963855385780334,
#       'rougeLsum_precision': 0.3333333432674408,
#       'rougeLsum_recall': 0.53125}]}},
#   {'panza_responses': ['Dear Ernie,\r\n\r\nMany thanks for the invitation, but I am afraid I cannot make it this year. I am trying to get some other admin tasks done this semester.\r\n\r\nBest regards,\r\nDavid'],
#    'golden_responses': ["Dear Ernie,\r\n\r\nThank you for the invitation. I would have loved to join, but I'm trying to save some time\r\nand energy for my other admin tasks this semester :-)\r\n\r\nBest regards,\r\nDavid"],
#    'scores': {'BLEU': [0.37843263149261475],
#     'ROUGE': [{'rouge1_fmeasure': 0.5625,
#       'rouge1_precision': 0.5625,
#       'rouge1_recall': 0.5625,
#       'rouge2_fmeasure': 0.32258063554763794,
#       'rouge2_precision': 0.32258063554763794,
#       'rouge2_recall': 0.32258063554763794,
#       'rougeL_fmeasure': 0.53125,
#       'rougeL_precision': 0.53125,
#       'rougeL_recall': 0.53125,
#       'rougeLsum_fmeasure': 0.53125,
#       'rougeLsum_precision': 0.53125,
#       'rougeLsum_recall': 0.53125}]}},
#   {'panza_responses': ["That's great news. I was about to investigate this myself, so many thanks for\r\nlooking into it!\r\n\r\nDavid"],
#    'golden_responses': ["That's great news, thank you so much for looking into it."],
#    'scores': {'BLEU': [0.3243817389011383],
#     'ROUGE': [{'rouge1_fmeasure': 0.5517241358757019,
#       'rouge1_precision': 0.4444444477558136,
#       'rouge1_recall': 0.7272727489471436,
#       'rouge2_fmeasure': 0.37037035822868347,
#       'rouge2_precision': 0.29411765933036804,
#       'rouge2_recall': 0.5,
#       'rougeL_fmeasure': 0.5517241358757019,
#       'rougeL_precision': 0.4444444477558136,
#       'rougeL_recall': 0.7272727489471436,
#       'rougeLsum_fmeasure': 0.5517241358757019,
#       'rougeLsum_precision': 0.4444444477558136,
#       'rougeLsum_recall': 0.7272727489471436}]}},
#   {'panza_responses': ['Dear Xing,\r\n\r\nI need to discuss a few things with my colleagues, and I plan to send you\r\nthe form by Monday.\r\n\r\nBest regards,\r\nDavid'],
#    'golden_responses': ['Dear Xing,\r\n\r\nI need to arrange some details with my colleagues, but I plan to provide you\r\nwith the form by Monday or so.\r\n\r\nBest,\r\nDavid'],
#    'scores': {'BLEU': [0.5047461986541748],
#     'ROUGE': [{'rouge1_fmeasure': 0.7058823704719543,
#       'rouge1_precision': 0.7200000286102295,
#       'rouge1_recall': 0.692307710647583,
#       'rouge2_fmeasure': 0.44897958636283875,
#       'rouge2_precision': 0.4583333432674408,
#       'rouge2_recall': 0.4399999976158142,
#       'rougeL_fmeasure': 0.7058823704719543,
#       'rougeL_precision': 0.7200000286102295,
#       'rougeL_recall': 0.692307710647583,
#       'rougeLsum_fmeasure': 0.7058823704719543,
#       'rougeLsum_precision': 0.7200000286102295,
#       'rougeLsum_recall': 0.692307710647583}]}},
#   {'panza_responses': ['Hi,\r\n\r\nI am around in Palo Alto and available on either June 26th or June 28th--please\r\nlet me know what would work for you.\r\n\r\nBest,\r\nDavid'],
#    'golden_responses': ['Sounds good. I should be around Palo Alto and available either on the 26th\r\nor on the 28th of June.\r\nPlease let me know what works for you.\r\n\r\nCheers,\r\nDavid'],
#    'scores': {'BLEU': [0.3716883361339569],
#     'ROUGE': [{'rouge1_fmeasure': 0.6428571343421936,
#       'rouge1_precision': 0.692307710647583,
#       'rouge1_recall': 0.6000000238418579,
#       'rouge2_fmeasure': 0.29629629850387573,
#       'rouge2_precision': 0.3199999928474426,
#       'rouge2_recall': 0.27586206793785095,
#       'rougeL_fmeasure': 0.6071428656578064,
#       'rougeL_precision': 0.6538461446762085,
#       'rougeL_recall': 0.5666666626930237,
#       'rougeLsum_fmeasure': 0.6071428656578064,
#       'rougeLsum_precision': 0.6538461446762085,
#       'rougeLsum_recall': 0.5666666626930237}]}},
#   {'panza_responses': ['Dear Valentina,\r\n\r\nWe are just waiting for the organizers to finalize the payment process, and\r\nthen we should be done.\r\n\r\nBest regards,\r\nDavid'],
#    'golden_responses': ['Hi Valentina,\r\n\r\n\r\nNo, I am just waiting on the organizers to close the payments.\r\n\r\n Best regards,\r\nDavid'],
#    'scores': {'BLEU': [0.24006417393684387],
#     'ROUGE': [{'rouge1_fmeasure': 0.5,
#       'rouge1_precision': 0.43478259444236755,
#       'rouge1_recall': 0.5882353186607361,
#       'rouge2_fmeasure': 0.2631579041481018,
#       'rouge2_precision': 0.22727273404598236,
#       'rouge2_recall': 0.3125,
#       'rougeL_fmeasure': 0.5,
#       'rougeL_precision': 0.43478259444236755,
#       'rougeL_recall': 0.5882353186607361,
#       'rougeLsum_fmeasure': 0.5,
#       'rougeLsum_precision': 0.43478259444236755,
#       'rougeLsum_recall': 0.5882353186607361}]}},
#   {'panza_responses': ['Yes, I was about to write the same thing. I can review once a first pass is done.'],
#    'golden_responses': ["I was actually about to write the same thing, so I completely agree with\r\nPavel's observation.\r\nHappy to review once a first pass is done.\r\n\r\nBest regards,\r\nDavid"],
#    'scores': {'BLEU': [0.4338667392730713],
#     'ROUGE': [{'rouge1_fmeasure': 0.695652186870575,
#       'rouge1_precision': 0.8888888955116272,
#       'rouge1_recall': 0.5714285969734192,
#       'rouge2_fmeasure': 0.5454545617103577,
#       'rouge2_precision': 0.7058823704719543,
#       'rouge2_recall': 0.4444444477558136,
#       'rougeL_fmeasure': 0.695652186870575,
#       'rougeL_precision': 0.8888888955116272,
#       'rougeL_recall': 0.5714285969734192,
#       'rougeLsum_fmeasure': 0.695652186870575,
#       'rougeLsum_precision': 0.8888888955116272,
#       'rougeLsum_recall': 0.5714285969734192}]}},
#   {'panza_responses': ['Hi,\r\n\r\nNo major plans for the week, so feel free to suggest a day that\r\nworks for you (Wednesday would be fine for me).\r\n\r\nBest,\r\nDavid'],
#    'golden_responses': ["Nice! I don't have any big plans for next week, so any day that works for\r\nyou is fine for me as well. Maybe Wednesday?\r\n\r\nDavid"],
#    'scores': {'BLEU': [0.37083449959754944],
#     'ROUGE': [{'rouge1_fmeasure': 0.5384615659713745,
#       'rouge1_precision': 0.5384615659713745,
#       'rouge1_recall': 0.5384615659713745,
#       'rouge2_fmeasure': 0.3199999928474426,
#       'rouge2_precision': 0.3199999928474426,
#       'rouge2_recall': 0.3199999928474426,
#       'rougeL_fmeasure': 0.5,
#       'rougeL_precision': 0.5,
#       'rougeL_recall': 0.5,
#       'rougeLsum_fmeasure': 0.5,
#       'rougeLsum_precision': 0.5,
#       'rougeLsum_recall': 0.5}]}},
#   {'panza_responses': ['Hi,\r\n\r\nWhich email should I use for you for the registration?\r\n\r\nBest,\r\nDavid'],
#    'golden_responses': ['Hi,\r\n\r\nWhich email should I use for you for the registration?\r\n\r\nBest,\r\nDavid'],
#    'scores': {'BLEU': [1.0],
#     'ROUGE': [{'rouge1_fmeasure': 1.0,
#       'rouge1_precision': 1.0,
#       'rouge1_recall': 1.0,
#       'rouge2_fmeasure': 1.0,
#       'rouge2_precision': 1.0,
#       'rouge2_recall': 1.0,
#       'rougeL_fmeasure': 1.0,
#       'rougeL_precision': 1.0,
#       'rougeL_recall': 1.0,
#       'rougeLsum_fmeasure': 1.0,
#       'rougeLsum_precision': 1.0,
#       'rougeLsum_recall': 1.0}]}},
#   {'panza_responses': ['Hey, I just messaged you on WhatsApp. I have a lot of meetings today, but\r\nI am around most of the day.'],
#    'golden_responses': ['Hey, I just messaged you on WhatsApp. I am around for most of the day\r\ntoday. I have a bunch of meetings but would love to chat.'],
#    'scores': {'BLEU': [0.6078152656555176],
#     'ROUGE': [{'rouge1_fmeasure': 0.8571428656578064,
#       'rouge1_precision': 0.9545454382896423,
#       'rouge1_recall': 0.7777777910232544,
#       'rouge2_fmeasure': 0.6382978558540344,
#       'rouge2_precision': 0.7142857313156128,
#       'rouge2_recall': 0.5769230723381042,
#       'rougeL_fmeasure': 0.5714285969734192,
#       'rougeL_precision': 0.6363636255264282,
#       'rougeL_recall': 0.5185185074806213,
#       'rougeLsum_fmeasure': 0.5714285969734192,
#       'rougeLsum_precision': 0.6363636255264282,
#       'rougeLsum_recall': 0.5185185074806213}]}},
#   {'panza_responses': ['Thanks for your email, I encourage you to apply!\r\nI would be a potential supervisor.\r\n\r\nCheers,\r\nDavid'],
#    'golden_responses': ['Thanks for your email, I encourage you to apply and mention me as a\r\npotential supervisor.\r\n\r\nCheers,\r\nDavid'],
#    'scores': {'BLEU': [0.7189090847969055],
#     'ROUGE': [{'rouge1_fmeasure': 0.800000011920929,
#       'rouge1_precision': 0.8235294222831726,
#       'rouge1_recall': 0.7777777910232544,
#       'rouge2_fmeasure': 0.7272727489471436,
#       'rouge2_precision': 0.75,
#       'rouge2_recall': 0.7058823704719543,
#       'rougeL_fmeasure': 0.800000011920929,
#       'rougeL_precision': 0.8235294222831726,
#       'rougeL_recall': 0.7777777910232544,
#       'rougeLsum_fmeasure': 0.800000011920929,
#       'rougeLsum_precision': 0.8235294222831726,
#       'rougeLsum_recall': 0.7777777910232544}]}},
#   {'panza_responses': ["Hi,\r\n\r\nI am around this afternoon if you'd like to meet.\r\n\r\nBest,\r\nDavid"],
#    'golden_responses': ['OK, let me know what times would work for you in the afternoon.\r\n\r\nDavid'],
#    'scores': {'BLEU': [0.03561389073729515],
#     'ROUGE': [{'rouge1_fmeasure': 0.14814814925193787,
#       'rouge1_precision': 0.1538461595773697,
#       'rouge1_recall': 0.1428571492433548,
#       'rouge2_fmeasure': 0.0,
#       'rouge2_precision': 0.0,
#       'rouge2_recall': 0.0,
#       'rougeL_fmeasure': 0.14814814925193787,
#       'rougeL_precision': 0.1538461595773697,
#       'rougeL_recall': 0.1428571492433548,
#       'rougeLsum_fmeasure': 0.14814814925193787,
#       'rougeLsum_precision': 0.1538461595773697,
#       'rougeLsum_recall': 0.1428571492433548}]}},
#   {'panza_responses': ["Hi,\r\n\r\nSorry for my unavailability today, I'm traveling (at BOS right now). I'll be\r\naround for about 30 minutes after I get back.\r\n\r\nBest,\r\nDavid"],
#    'golden_responses': ["Hi,\r\n\r\nSorry, I've been traveling in the past week (in BOS now). I should be\r\navailable for the next 30 minutes or so.\r\n\r\nBest,\r\nDavid"],
#    'scores': {'BLEU': [0.18123723566532135],
#     'ROUGE': [{'rouge1_fmeasure': 0.47999998927116394,
#       'rouge1_precision': 0.47999998927116394,
#       'rouge1_recall': 0.47999998927116394,
#       'rouge2_fmeasure': 0.125,
#       'rouge2_precision': 0.125,
#       'rouge2_recall': 0.125,
#       'rougeL_fmeasure': 0.4399999976158142,
#       'rougeL_precision': 0.4399999976158142,
#       'rougeL_recall': 0.4399999976158142,
#       'rougeLsum_fmeasure': 0.4399999976158142,
#       'rougeLsum_precision': 0.4399999976158142,
#       'rougeLsum_recall': 0.4399999976158142}]}},
#   {'panza_responses': ['Yes, for each flight, I would need 1 checked bag please.\r\n\r\nDavid'],
#    'golden_responses': ['Yes, this is correct. I would need 1 checked bag for each flight please.\r\n\r\nBest regards,\r\nDavid'],
#    'scores': {'BLEU': [0.5028508305549622],
#     'ROUGE': [{'rouge1_fmeasure': 0.8275862336158752,
#       'rouge1_precision': 1.0,
#       'rouge1_recall': 0.7058823704719543,
#       'rouge2_fmeasure': 0.5185185074806213,
#       'rouge2_precision': 0.6363636255264282,
#       'rouge2_recall': 0.4375,
#       'rougeL_fmeasure': 0.6206896305084229,
#       'rougeL_precision': 0.75,
#       'rougeL_recall': 0.529411792755127,
#       'rougeLsum_fmeasure': 0.6206896305084229,
#       'rougeLsum_precision': 0.75,
#       'rougeLsum_recall': 0.529411792755127}]}},
#   {'panza_responses': ['Thanks, great! I will handle the sponsorship request from my side.\r\n\r\nBest regards,\r\nDavid'],
#    'golden_responses': ['Thank you, great to have you on board! I will handle the sponsorship\r\nrequest from my side.\r\n\r\nDavid'],
#    'scores': {'BLEU': [0.5191128253936768],
#     'ROUGE': [{'rouge1_fmeasure': 0.6875,
#       'rouge1_precision': 0.7857142686843872,
#       'rouge1_recall': 0.6111111044883728,
#       'rouge2_fmeasure': 0.5333333611488342,
#       'rouge2_precision': 0.6153846383094788,
#       'rouge2_recall': 0.47058823704719543,
#       'rougeL_fmeasure': 0.6875,
#       'rougeL_precision': 0.7857142686843872,
#       'rougeL_recall': 0.6111111044883728,
#       'rougeLsum_fmeasure': 0.6875,
#       'rougeLsum_precision': 0.7857142686843872,
#       'rougeLsum_recall': 0.6111111044883728}]}},
#   {'panza_responses': ["Dear Dragan,\r\n\r\nI wanted to send you this paper, which we've been using in our group for\r\na while now:\r\n\r\nhttps://arxiv.org/pdf/2310.135454.pdf\r\n\r\nThe main observation is that the authors were able to get a speedup of around\r\n7x.\r\n\r\nCheers,\r\nDavid"],
#    'golden_responses': ["Hi Dragan,\r\n\r\nHere's the paper I mentioned today:\r\n\r\nhttps://arxiv.org/pdf/2310.069288.pdf\r\n\r\nTLDR: we compress to ~70% and quantize during finetuning, and get\r\nabout 7x speedup.\r\n\r\nCheers,\r\nDavid"],
#    'scores': {'BLEU': [0.0846385657787323],
#     'ROUGE': [{'rouge1_fmeasure': 0.3125,
#       'rouge1_precision': 0.25641027092933655,
#       'rouge1_recall': 0.4000000059604645,
#       'rouge2_fmeasure': 0.032258063554763794,
#       'rouge2_precision': 0.02631578966975212,
#       'rouge2_recall': 0.0416666679084301,
#       'rougeL_fmeasure': 0.21875,
#       'rougeL_precision': 0.1794871836900711,
#       'rougeL_recall': 0.2800000011920929,
#       'rougeLsum_fmeasure': 0.21875,
#       'rougeLsum_precision': 0.1794871836900711,
#       'rougeLsum_recall': 0.2800000011920929}]}},
#   {'panza_responses': ['Dear Davidny,\r\n\r\nThank you for your email, I am afraid I cannot take you on as an intern\r\nthis year, since I am on leave for the next year.\r\n\r\nBest regards,\r\nDavid'],
#    'golden_responses': ['Dear Davidny,\r\n\r\nThank you for your email, but unfortunately we do not have any internship\r\nslots for the next year, since I will be on leave.\r\n\r\nBest regards,\r\nDavid'],
#    'scores': {'BLEU': [0.45726385712623596],
#     'ROUGE': [{'rouge1_fmeasure': 0.5901639461517334,
#       'rouge1_precision': 0.5625,
#       'rouge1_recall': 0.6206896305084229,
#       'rouge2_fmeasure': 0.47457626461982727,
#       'rouge2_precision': 0.4516128897666931,
#       'rouge2_recall': 0.5,
#       'rougeL_fmeasure': 0.49180328845977783,
#       'rougeL_precision': 0.46875,
#       'rougeL_recall': 0.517241358757019,
#       'rougeLsum_fmeasure': 0.49180328845977783,
#       'rougeLsum_precision': 0.46875,
#       'rougeLsum_recall': 0.517241358757019}]}},
#   {'panza_responses': ["Thank you so much for your original email!\r\nI'm glad to have received it.\r\n\r\nBest regards,\r\nDavid"],
#    'golden_responses': ['Thank you so much! Indeed, I missed your original email.\r\n\r\nBest regards,\r\nDavid'],
#    'scores': {'BLEU': [0.4423884451389313],
#     'ROUGE': [{'rouge1_fmeasure': 0.6666666865348816,
#       'rouge1_precision': 0.5882353186607361,
#       'rouge1_recall': 0.7692307829856873,
#       'rouge2_fmeasure': 0.5,
#       'rouge2_precision': 0.4375,
#       'rouge2_recall': 0.5833333134651184,
#       'rougeL_fmeasure': 0.6666666865348816,
#       'rougeL_precision': 0.5882353186607361,
#       'rougeL_recall': 0.7692307829856873,
# ...
#    'golden_responses': ['Hi,\r\n\r\nI booked the restaurant at 18:30, and Alex will join as well.\r\n\r\nDavid'],
#    'scores': {'BLEU': [0.782307505607605],
#     'ROUGE': [{'rouge1_fmeasure': 0.8571428656578064,
#       'rouge1_precision': 0.8571428656578064,
#       'rouge1_recall': 0.8571428656578064,
#       'rouge2_fmeasure': 0.7692307829856873,
#       'rouge2_precision': 0.7692307829856873,
#       'rouge2_recall': 0.7692307829856873,
#       'rougeL_fmeasure': 0.8571428656578064,
#       'rougeL_precision': 0.8571428656578064,
#       'rougeL_recall': 0.8571428656578064,
#       'rougeLsum_fmeasure': 0.8571428656578064,
#       'rougeLsum_precision': 0.8571428656578064,
#       'rougeLsum_recall': 0.8571428656578064}]}},
#   {'panza_responses': ['Hi,\r\n\r\nUnfortunately I cannot make it on Tuesday, would Monday work for you? I\r\ncould meet you at the train station (right in front of the main entrance).\r\n\r\nBest,\r\nDavid'],
#    'golden_responses': ["Yes, unfortunately something came up and I can't make Tuesday. Would Monday\r\nwork for you at all? We could go to a place that's close to your apartment."],
#    'scores': {'BLEU': [0.26241910457611084],
#     'ROUGE': [{'rouge1_fmeasure': 0.37931033968925476,
#       'rouge1_precision': 0.36666667461395264,
#       'rouge1_recall': 0.3928571343421936,
#       'rouge2_fmeasure': 0.2142857164144516,
#       'rouge2_precision': 0.2068965584039688,
#       'rouge2_recall': 0.2222222238779068,
#       'rougeL_fmeasure': 0.3448275923728943,
#       'rougeL_precision': 0.3333333432674408,
#       'rougeL_recall': 0.3571428656578064,
#       'rougeLsum_fmeasure': 0.3448275923728943,
#       'rougeLsum_precision': 0.3333333432674408,
#       'rougeLsum_recall': 0.3571428656578064}]}},
#   {'panza_responses': ["Cheers,\r\nI'm really glad to hear this!\r\n\r\nDavid"],
#    'golden_responses': ["Hey,\r\n\r\nI'm really glad to hear that, looking forward to having you on board!\r\n\r\nCheers,\r\nDavid"],
#    'scores': {'BLEU': [0.25516197085380554],
#     'ROUGE': [{'rouge1_fmeasure': 0.5833333134651184,
#       'rouge1_precision': 0.875,
#       'rouge1_recall': 0.4375,
#       'rouge2_fmeasure': 0.3636363744735718,
#       'rouge2_precision': 0.5714285969734192,
#       'rouge2_recall': 0.2666666805744171,
#       'rougeL_fmeasure': 0.5,
#       'rougeL_precision': 0.75,
#       'rougeL_recall': 0.375,
#       'rougeLsum_fmeasure': 0.5,
#       'rougeLsum_precision': 0.75,
#       'rougeLsum_recall': 0.375}]}},
#   {'panza_responses': ["Hi,\r\n\r\nThanks, that's great news on our side of the deal.\r\n\r\nNow, I am wondering if there is anything I can do to convince you to accept the\r\noffer.\r\n\r\nBest,\r\nDavid"],
#    'golden_responses': ['I am really glad it worked out on our side. Now, please let me know if I\r\ncan do anything to convince you to accept the offer :-)\r\n\r\nDavid'],
#    'scores': {'BLEU': [0.4405522048473358],
#     'ROUGE': [{'rouge1_fmeasure': 0.6440678238868713,
#       'rouge1_precision': 0.6129032373428345,
#       'rouge1_recall': 0.6785714030265808,
#       'rouge2_fmeasure': 0.38596490025520325,
#       'rouge2_precision': 0.36666667461395264,
#       'rouge2_recall': 0.40740740299224854,
#       'rougeL_fmeasure': 0.5423728823661804,
#       'rougeL_precision': 0.5161290168762207,
#       'rougeL_recall': 0.5714285969734192,
#       'rougeLsum_fmeasure': 0.5423728823661804,
#       'rougeLsum_precision': 0.5161290168762207,
#       'rougeLsum_recall': 0.5714285969734192}]}},
#   {'panza_responses': ['Thanks so much for thinking of me, I would be more than happy to have a look!\r\n\r\nBest,\r\nDavid'],
#    'golden_responses': ['Alright, thanks for being so thoughtful on this.\r\n\r\nBest,\r\nDavid'],
#    'scores': {'BLEU': [0.09601765125989914],
#     'ROUGE': [{'rouge1_fmeasure': 0.3448275923728943,
#       'rouge1_precision': 0.2631579041481018,
#       'rouge1_recall': 0.5,
#       'rouge2_fmeasure': 0.07407407462596893,
#       'rouge2_precision': 0.0555555559694767,
#       'rouge2_recall': 0.1111111119389534,
#       'rougeL_fmeasure': 0.27586206793785095,
#       'rougeL_precision': 0.21052631735801697,
#       'rougeL_recall': 0.4000000059604645,
#       'rougeLsum_fmeasure': 0.27586206793785095,
#       'rougeLsum_precision': 0.21052631735801697,
#       'rougeLsum_recall': 0.4000000059604645}]}},
#   {'panza_responses': ['Hi,\r\n\r\nCould you please let me know what timeline you had in mind? Also, I\r\nassume the meeting would be virtual.\r\n\r\nBest,\r\nDavid'],
#    'golden_responses': ['Hi,\r\n\r\nCan you please let me know what timeline you have in mind? Also, I imagine\r\nthe talk would be virtual?\r\n\r\nBest,\r\nDavid'],
#    'scores': {'BLEU': [0.6944512724876404],
#     'ROUGE': [{'rouge1_fmeasure': 0.8260869383811951,
#       'rouge1_precision': 0.8260869383811951,
#       'rouge1_recall': 0.8260869383811951,
#       'rouge2_fmeasure': 0.6363636255264282,
#       'rouge2_precision': 0.6363636255264282,
#       'rouge2_recall': 0.6363636255264282,
#       'rougeL_fmeasure': 0.8260869383811951,
#       'rougeL_precision': 0.8260869383811951,
#       'rougeL_recall': 0.8260869383811951,
#       'rougeLsum_fmeasure': 0.8260869383811951,
#       'rougeLsum_precision': 0.8260869383811951,
#       'rougeLsum_recall': 0.8260869383811951}]}},
#   {'panza_responses': ["Hi,\r\n\r\nYes, that's a great topic! I didn't see your email, sorry about that.\r\n\r\nI'll have to take a look.\r\n\r\nBest,\r\nDavid"],
#    'golden_responses': ['Thanks, this sounds interesting. I will try to have a look.'],
#    'scores': {'BLEU': [0.08282601088285446],
#     'ROUGE': [{'rouge1_fmeasure': 0.3030303120613098,
#       'rouge1_precision': 0.22727273404598236,
#       'rouge1_recall': 0.4545454680919647,
#       'rouge2_fmeasure': 0.06451612710952759,
#       'rouge2_precision': 0.0476190485060215,
#       'rouge2_recall': 0.10000000149011612,
#       'rougeL_fmeasure': 0.24242424964904785,
#       'rougeL_precision': 0.1818181872367859,
#       'rougeL_recall': 0.3636363744735718,
#       'rougeLsum_fmeasure': 0.24242424964904785,
#       'rougeLsum_precision': 0.1818181872367859,
#       'rougeLsum_recall': 0.3636363744735718}]}},
#   {'panza_responses': ['Hi all,\r\n\r\nThe weekly meeting has been moved to Monday at 14:30, since we have\r\nsome administrative meetings in the morning.\r\n\r\nBest,\r\nDavid'],
#    'golden_responses': ['Hi all,\r\n\r\nDue to administrative meetings earlier in the day, our weekly group meeting\r\nis Monday at *14:30*:\r\n\r\n\r\n\r\nSee you,\r\nDavid'],
#    'scores': {'BLEU': [0.27662867307662964],
#     'ROUGE': [{'rouge1_fmeasure': 0.5909090638160706,
#       'rouge1_precision': 0.5652173757553101,
#       'rouge1_recall': 0.6190476417541504,
#       'rouge2_fmeasure': 0.2380952388048172,
#       'rouge2_precision': 0.22727273404598236,
#       'rouge2_recall': 0.25,
#       'rougeL_fmeasure': 0.40909090638160706,
#       'rougeL_precision': 0.3913043439388275,
#       'rougeL_recall': 0.4285714328289032,
#       'rougeLsum_fmeasure': 0.40909090638160706,
#       'rougeLsum_precision': 0.3913043439388275,
#       'rougeLsum_recall': 0.4285714328289032}]}},
#   {'panza_responses': ['Hi all,\r\n\r\nA quick reminder that the group meeting is this week on Monday at 11:00.\r\n\r\nAlso, I wanted to suggest having our group dinner on Thursday at 7pm at TIKA\r\ninstead of today. \r\n\r\nBest,\r\nDavid'],
#    'golden_responses': ['Dear all,\r\n\r\nThe group meeting is happening on Monday at 11:00 this week.\r\n\r\n\r\n\r\nRegarding the group dinner, I wanted to suggest Thursday around 7pm at TIKA\r\n.\r\n\r\nBest regards,\r\nDavid'],
#    'scores': {'BLEU': [0.4374382197856903],
#     'ROUGE': [{'rouge1_fmeasure': 0.7076923251152039,
#       'rouge1_precision': 0.6388888955116272,
#       'rouge1_recall': 0.7931034564971924,
#       'rouge2_fmeasure': 0.4126984179019928,
#       'rouge2_precision': 0.37142857909202576,
#       'rouge2_recall': 0.4642857015132904,
#       'rougeL_fmeasure': 0.5846154093742371,
#       'rougeL_precision': 0.5277777910232544,
#       'rougeL_recall': 0.6551724076271057,
#       'rougeLsum_fmeasure': 0.5846154093742371,
#       'rougeLsum_precision': 0.5277777910232544,
#       'rougeLsum_recall': 0.6551724076271057}]}},
#   {'panza_responses': ['Hi,\r\n\r\nYes, I confirm that you are the one we would like to award the position to.\r\nDavid'],
#    'golden_responses': ['Hi,\r\n\r\nYes, I confirm that she should receive the position.\r\n\r\nDavid'],
#    'scores': {'BLEU': [0.33389192819595337],
#     'ROUGE': [{'rouge1_fmeasure': 0.5517241358757019,
#       'rouge1_precision': 0.4444444477558136,
#       'rouge1_recall': 0.7272727489471436,
#       'rouge2_fmeasure': 0.37037035822868347,
#       'rouge2_precision': 0.29411765933036804,
#       'rouge2_recall': 0.5,
#       'rougeL_fmeasure': 0.5517241358757019,
#       'rougeL_precision': 0.4444444477558136,
#       'rougeL_recall': 0.7272727489471436,
#       'rougeLsum_fmeasure': 0.5517241358757019,
#       'rougeLsum_precision': 0.4444444477558136,
#       'rougeLsum_recall': 0.7272727489471436}]}},
#   {'panza_responses': ['Sorry, I have no idea how your emails ended up in the spam folder. Please find the form attached.\r\n\r\nDavid'],
#    'golden_responses': ['Sorry, for some reason all your emails landed in my spam folder.\r\n\r\nPlease find the form attached.\r\n\r\nDavid'],
#    'scores': {'BLEU': [0.4844127595424652],
#     'ROUGE': [{'rouge1_fmeasure': 0.6315789222717285,
#       'rouge1_precision': 0.6000000238418579,
#       'rouge1_recall': 0.6666666865348816,
#       'rouge2_fmeasure': 0.4444444477558136,
#       'rouge2_precision': 0.42105263471603394,
#       'rouge2_recall': 0.47058823704719543,
#       'rougeL_fmeasure': 0.6315789222717285,
#       'rougeL_precision': 0.6000000238418579,
#       'rougeL_recall': 0.6666666865348816,
#       'rougeLsum_fmeasure': 0.6315789222717285,
#       'rougeLsum_precision': 0.6000000238418579,
#       'rougeLsum_recall': 0.6666666865348816}]}},
#   {'panza_responses': ['Dear Adam,\r\n\r\nI wanted to thank you for your email, but I have managed to do it myself.\r\n\r\nBest regards,\r\nDavid'],
#    'golden_responses': ['Hi Adam,\r\n\r\nThanks, I have finally managed to do this myself.\r\n\r\nCheers,\r\nDavid'],
#    'scores': {'BLEU': [0.19108586013317108],
#     'ROUGE': [{'rouge1_fmeasure': 0.47058823704719543,
#       'rouge1_precision': 0.380952388048172,
#       'rouge1_recall': 0.6153846383094788,
#       'rouge2_fmeasure': 0.1875,
#       'rouge2_precision': 0.15000000596046448,
#       'rouge2_recall': 0.25,
#       'rougeL_fmeasure': 0.47058823704719543,
#       'rougeL_precision': 0.380952388048172,
#       'rougeL_recall': 0.6153846383094788,
#       'rougeLsum_fmeasure': 0.47058823704719543,
#       'rougeLsum_precision': 0.380952388048172,
#       'rougeLsum_recall': 0.6153846383094788}]}},
#   {'panza_responses': ['Hi all,\r\n\r\nUnfortunately I have a scheduling conflict, so I would like to move the\r\nmeeting to the afternoon some time. Alternatively, I would be fine with\r\nthe original time (10am).\r\n\r\nBest regards,\r\nDavid'],
#    'golden_responses': ["Hi all,\r\n\r\nI was wondering if it would be possible to move the meeting to some point\r\nin the afternoon, due to a scheduling conflict. If it's not possible, then\r\nlet's have it at the agreed time (10am).\r\n\r\nBest,\r\nDavid"],
#    'scores': {'BLEU': [0.345856249332428],
#     'ROUGE': [{'rouge1_fmeasure': 0.5945945978164673,
#       'rouge1_precision': 0.6470588445663452,
#       'rouge1_recall': 0.550000011920929,
#       'rouge2_fmeasure': 0.3055555522441864,
#       'rouge2_precision': 0.3333333432674408,
#       'rouge2_recall': 0.28205129504203796,
#       'rougeL_fmeasure': 0.4324324429035187,
#       'rougeL_precision': 0.47058823704719543,
#       'rougeL_recall': 0.4000000059604645,
#       'rougeLsum_fmeasure': 0.4324324429035187,
#       'rougeLsum_precision': 0.47058823704719543,
#       'rougeLsum_recall': 0.4000000059604645}]}},
#   {'panza_responses': ['Dear Steven,\r\n\r\nI am so sorry for the delay, would it be OK if I submit the article\r\nin a couple of days, i.e. early next week?\r\n\r\nBest regards,\r\nDavid'],
#    'golden_responses': ['Dear Steven,\r\n\r\nUnfortunately I am a bit delayed on this, would it be possible to have\r\nuntil early next week to complete the article?\r\n\r\nBest regards,\r\nDavid'],
#    'scores': {'BLEU': [0.3002370595932007],
#     'ROUGE': [{'rouge1_fmeasure': 0.5614035129547119,
#       'rouge1_precision': 0.5333333611488342,
#       'rouge1_recall': 0.5925925970077515,
#       'rouge2_fmeasure': 0.3272727131843567,
#       'rouge2_precision': 0.3103448152542114,
#       'rouge2_recall': 0.3461538553237915,
#       'rougeL_fmeasure': 0.45614033937454224,
#       'rougeL_precision': 0.4333333373069763,
#       'rougeL_recall': 0.48148149251937866,
#       'rougeLsum_fmeasure': 0.45614033937454224,
#       'rougeLsum_precision': 0.4333333373069763,
#       'rougeLsum_recall': 0.48148149251937866}]}},
#   {'panza_responses': ["Hey,\r\n\r\nI'm fine, just late because I was spending time with a collaborator.\r\n\r\nBest,\r\nDavid"],
#    'golden_responses': ["Hey,\r\n\r\nNo, I'm fine, I just spent a bit more time talking to a collaborator so I'm late. In\r\nthe waiting room now.\r\n\r\nBest,\r\nDavid"],
#    'scores': {'BLEU': [0.14500771462917328],
#     'ROUGE': [{'rouge1_fmeasure': 0.550000011920929,
#       'rouge1_precision': 0.7333333492279053,
#       'rouge1_recall': 0.4399999976158142,
#       'rouge2_fmeasure': 0.15789473056793213,
#       'rouge2_precision': 0.2142857164144516,
#       'rouge2_recall': 0.125,
#       'rougeL_fmeasure': 0.44999998807907104,
#       'rougeL_precision': 0.6000000238418579,
#       'rougeL_recall': 0.36000001430511475,
#       'rougeLsum_fmeasure': 0.44999998807907104,
#       'rougeLsum_precision': 0.6000000238418579,
#       'rougeLsum_recall': 0.36000001430511475}]}},
#   {'panza_responses': ['Hi Markus,\r\n\r\nUnfortunately I will be late on campus, I hope to be around 11.\r\n\r\nBest,\r\nDavid'],
#    'golden_responses': ['Hi Markus,\r\n\r\nUnfortunately I will be late to campus today. I hope to be there around 11.\r\n\r\nBest,\r\nDavid'],
#    'scores': {'BLEU': [0.7078836560249329],
#     'ROUGE': [{'rouge1_fmeasure': 0.8888888955116272,
#       'rouge1_precision': 0.9411764740943909,
#       'rouge1_recall': 0.8421052694320679,
#       'rouge2_fmeasure': 0.7058823704719543,
#       'rouge2_precision': 0.75,
#       'rouge2_recall': 0.6666666865348816,
#       'rougeL_fmeasure': 0.8888888955116272,
#       'rougeL_precision': 0.9411764740943909,
#       'rougeL_recall': 0.8421052694320679,
#       'rougeLsum_fmeasure': 0.8888888955116272,
#       'rougeLsum_precision': 0.9411764740943909,
#       'rougeLsum_recall': 0.8421052694320679}]}},
#   {'panza_responses': ["Hi,\r\n\r\nI don't have an exact answer for you, but I would guess around 3-4 weeks.\r\n\r\nBest,\r\nDavid"],
#    'golden_responses': ["Yes. I don't have an exact answer, my guess is in 3-4 weeks."],
#    'scores': {'BLEU': [0.3949797749519348],
#     'ROUGE': [{'rouge1_fmeasure': 0.5806451439857483,
#       'rouge1_precision': 0.5,
#       'rouge1_recall': 0.692307710647583,
#       'rouge2_fmeasure': 0.4137931168079376,
#       'rouge2_precision': 0.3529411852359772,
#       'rouge2_recall': 0.5,
#       'rougeL_fmeasure': 0.5806451439857483,
#       'rougeL_precision': 0.5,
#       'rougeL_recall': 0.692307710647583,
#       'rougeLsum_fmeasure': 0.5806451439857483,
#       'rougeLsum_precision': 0.5,
#       'rougeLsum_recall': 0.692307710647583}]}}],
#  'aggregate_metrics': {'BLEU': np.float64(0.416107937918011),
#   'ROUGE': {'rouge1_fmeasure': np.float64(0.6171970923981035),
#    'rouge1_precision': np.float64(0.6396843248821167),
#    'rouge1_recall': np.float64(0.6176533339073859),
#    'rouge2_fmeasure': np.float64(0.40317841349955064),
#    'rouge2_precision': np.float64(0.417258518534791),
#    'rouge2_recall': np.float64(0.40222867609686164),
#    'rougeL_fmeasure': np.float64(0.5640072697796017),
#    'rougeL_precision': np.float64(0.5833571008350475),
#    'rougeL_recall': np.float64(0.5642776719956513),
#    'rougeLsum_fmeasure': np.float64(0.5640072697796017),
#    'rougeLsum_precision': np.float64(0.5833571008350475),
#    'rougeLsum_recall': np.float64(0.5642776719956513)},
#   'MAUVE': np.float64(0.9806815434374475)}}
